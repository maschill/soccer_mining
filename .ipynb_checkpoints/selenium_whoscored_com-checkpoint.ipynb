# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException

import os
import json
from urllib.request import urlopen, Request

import sys
import time

from unidecode import unidecode

import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import sqlite3

from datetime import datetime
from difflib import SequenceMatcher

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import scrape_selenium_soccerway as utils

# %%
#convert string of type x% to a float 
def perc2float(string):
    s =string.strip() 
    if s[-1]=='%':
        return float(s.strip("%"))/100
    return string

#converts date string of type dd-mon-YY to datetime
def str2date(string):
    helper = { 'Sep':9, 'Aug':8, 'Jul':7, 'Jun':6, 'May':5, 'Apr':4, 'Mar':3, 'Feb':2, 'Jan':1, 'Oct':10, 'Nov':11, 'Dec': 12 }
    s = string.split('-')
    return(datetime(int(''.join(['20',s[2]])), helper[s[1]], int(s[0])))

#converts date string of type dd-mon-YY to datetime
def str2date2(string):
    helper = { 'Sep':9, 'Aug':8, 'Jul':7, 'Jun':6, 'May':5, 'Apr':4, 'Mar':3, 'Feb':2, 'Jan':1, 'Oct':10, 'Nov':11, 'Dec': 12 }
    s = string.split(' ')
    return(datetime(int(s[2]), helper[s[1]], int(s[0])))

#
def dist(string1, string2):
    match = SequenceMatcher(None, string1, string2).find_longest_match(0,len(string1), 0, len(string2))
    return match.size

#
def map_names(list1, list2):
    if len(list1) != len(list2):
        print('lists do not have equal length')
        return None
    list12 = [x[0] for x in list1]
    indices = [np.argmax([dist(s2, s) for s2 in list12]) for s in list2]
    mapping = {}
    for i,ix in enumerate(indices):
        mapping[list2[i]] = list1[ix][1]
    return mapping

def find_patch_id(date):
    dates2patch = {datetime(2017,8,1): 158835,   
                datetime(2017,2,22): 158647,   
                datetime(2016,8,1): 158466,   
                datetime(2016,2,19): 158278,   
                datetime(2015,8,1): 158103,   
                datetime(2015,2,20): 157914,   
                datetime(2014,8,1): 157739,   
                datetime(2014,2,21): 157550,   
                datetime(2013,8,1): 157376,   
                datetime(2013,2,22): 157186,   
                datetime(2012,8,1): 157011,   
                datetime(2012,2,22): 156820,   
                datetime(2011,8,1): 156644,   
                datetime(2011,2,22): 156455,   
                datetime(2010,8,1): 156279,   
                datetime(2010,2,22): 156090,   
                datetime(2009,8,1): 155914,   
                datetime(2009,2,22): 155725,   
                datetime(2008,8,1): 155549}
    
    
    for d in dates2patch.keys():
        if date < d:
            continue
        else:
            return dates2patch[d]
    print('none found')
    return None
    

## players: list of players, first half of team 1, second half of team 2
## teams: teamIDs as seen in database
## database: name of database file
## c: sqlite3 cursor. 
## Either c or database must have a value. 
def player_name2playerID(players, teams, database=None, c=None, out=False):
    if not c:
        con = sqlite3.connect(database)
        c = con.cursor()
    query0 = [x for x in c.execute('SELECT name,playerID FROM player WHERE teamID IN ('+str(teams[0])+')')]
    query1 = [x for x in c.execute('SELECT name,playerID FROM player WHERE teamID IN ('+str(teams[1])+')')]
    if not c:
        con.close()
    playerIDs = []
    
    if len((players[0]+players[1])) != 36:
        print(len(players))
#         print('not the right amount of players provided, sorry')
#         return None
    
    homep = utils.match_club_names(query0, players[0])
    awayp = utils.match_club_names(query1, players[1])
    if out:
        for i in homep:
            print(i, ':', homep[i])
        for i in awayp:
            print(i, ':', awayp[i])
        
    for player in players[0]:
        playerIDs.append(homep[player][1])
    playerIDs += ['0']*(18-len(playerIDs))

    for player in players[1]:
        playerIDs.append(awayp[player][1])
    playerIDs += ['0']*(36-len(playerIDs))
    
    
    return playerIDs

# %%
#scrapes a match report from whoscored.com to a row in the match table
def get_match_stats(url, database, driver, team_mapping, ligaID, sleep_time = 0.35):
    
    # team_match_stats_box(home, away):  Shots, Shots on target, pass%, aerial duel %, dribbles, tackles, possesion%
    team_match_stats = []
    
    #store shot statistics(home, away): total shots, aus dem spiel, ruhender ball, konter, elfmeter, 
    #                                   eigentor, total shots, total goals, conversion rate
    attempts = []

    #store passing statistics(home, away): total passes, crosses, through balls, long balls, 
    #                                    short passes, total passes, average pass streak
    passes = []

    #store fouling statistics(home, away): total cards, cards cuz foul, cards cuz unproffesional, 
    #                                    cards cuz dive, cards cuz other, red cards, yellow cards,
    #                                    cards per foul, total fouls
    fouls = []

    #get player names
    names = []

    #get player names simplified (ohne umlaute, akzente, etc)
    names_simple = []

#     #adblock with add_extension
#     chop = webdriver.ChromeOptions()
#     chop.add_extension('/home/mace/Downloads/Adblock-Plus_v1.13.3.crx')
#     with webdriver.Chrome('/home/mace/Downloads/chromedriver', chrome_options=chop) as driver:    
    #load website
    driver.get(url)
    time.sleep(sleep_time)
    
    ## select meta data
    homeID,awayID = [team_mapping[x.text] for x pca vs ldain driver.find_elements_by_class_name('team-link ')]
    date = str2date(driver.find_element_by_xpath('//div[@id="match-header"]//div[position()=3]/dl/dd[position()=2]').text.split(' ')[1])
    matchID = url.split('/')[4]

    #select general team match stats
    for x in driver.find_elements_by_xpath('//div[@id = "match-report-team-statistics"]//span[contains(@class,"stat-value")]/span'):
        team_match_stats.append(perc2float(x.text))

    #scrape shot statistics
    for x in driver.find_elements_by_xpath('//div[@id = "live-goals"]//span[contains(@class,"stat-value")]/span'):
        attempts.append(perc2float(x.text))

    driver.execute_script('window.scrollBy(0,600)')

    #select passing statistics
    driver.find_element_by_xpath("//a[@href='#live-passes']").click()
    time.sleep(sleep_time)

    #scrape passing statistics
    for x in driver.find_elements_by_xpath('//div[@id = "live-passes"]//span[contains(@class,"stat-value")]/span'):
        passes.append(x.text)

    #select fouling statistics
    driver.find_element_by_xpath("//a[@href='#live-aggression']").click()
    time.sleep(sleep_time)

    #scrape fouling statistics
    for x in driver.find_elements_by_xpath('//div[@id = "live-aggression"]//span[contains(@class,"stat-value")]/span'):
        fouls.append(x.text)

    #go to player stats/site
    driver.get(url.replace('MatchReport', 'LiveStatistics'))
    time.sleep(sleep_time)
    #get player names
    #repeat looking until list is populated to give site time to load
    while len(names)< 36 or names[0] == '0':
        names = []
        names_simple = []
        k=driver.find_elements_by_xpath("//div[@id='live-player-home-stats']//a[@class='player-link']")
        for x in k:
            names.append(x.text.split('(')[0].strip())

        for x in k:
            names_simple.append(unidecode(x.text.split('(')[0].strip()))
            
        names += ['0']*(18-len(names))
        names_simple+= ['0']*(18-len(names_simple))
    
        k=driver.find_elements_by_xpath("//div[@id='live-player-away-stats']//a[@class='player-link']")
        for x in k:
            names.append(x.text.split('(')[0].strip())

        for x in k:
            names_simple.append(unidecode(x.text.split('(')[0].strip()))

        names += ['0']*(36-len(names))
        names_simple += ['0']*(36-len(names_simple))
     
    
    with sqlite3.connect(database) as connection:
        cursor = connection.cursor()
        onfield = player_name2playerID(names_simple, [homeID, awayID], c=cursor)
        match_stats = onfield+attempts[14:16]+team_match_stats+attempts[2:12]+attempts[16:]+passes[:10] + passes[12:]+fouls[-2:]+fouls[12:14]+fouls[10:12]+fouls[2:10]
        cursor.execute('INSERT OR IGNORE INTO match VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)', (matchID, ligaID, date, url, homeID, awayID, *match_stats))
# Out:
#   File "<ipython-input-4-04bd97400892>", line 35
#     homeID,awayID = [team_mapping[x.text] for x pca vs ldain driver.find_elements_by_class_name('team-link ')]
#                                                   ^
# SyntaxError: invalid syntax

# %%
len([229923158647, 198202158647, 193886158647, 150418158647, 115533158647, 193886158647, 203030158647, 192984158647, 192565158647, 195363158647, 164994158647, 177553158647, 212245158647, 198118158647, 164994158647, 115533158647, 115533158647, 115533158647, 188545158647, 188545158647, 237595158647, 167495158647, 231228158647, 121939158647, 190483158647, 156616158647, 9014158647, 156616158647, 231228158647, 231228158647, 9014158647, 178603158647, 45197158647, 189596158647, 168607158647, 190483158647])
# Out:
# 36

# %%
import glob

csv_files_dict = {14:glob.glob('soccer_odds/eng*'),
                  13:glob.glob('soccer_odds/epl_*'),
                  19:glob.glob('soccer_odds/bun*'),
                  20:glob.glob('soccer_odds/2bun*'),
                  53:glob.glob('soccer_odds/lali*'),
                  31:glob.glob('soccer_odds/seri*'),
                  16:glob.glob('soccer_odds/ligue*'),
                  10:glob.glob('soccer_odds/ere*'),
                  68:glob.glob('soccer_odds/superli*'),
                  60:glob.glob('soccer_odds/E2*'),
                  61:glob.glob('soccer_odds/E3*')}
                  

def date_conv(x):
    if len(str(x).split('/')) <3:
        return None
    d, m, y = str(x).split('/')
    return datetime(*[int(x) for x in [''.join(['20',y]), m, d]])

# %%
url_base = 'http://de.soccerway.com/national/germany/bundesliga/20162017/regular-season/r35823/matches/'
con = sqlite3.connect('soccer.sqlite')
c = con.cursor()

# %%
[x for x in c.execute('select match.ligaID, league.name, count(*) from league join match on match.ligaID = league.leagueID group by match.ligaID')]
# Out:
# [(10, 'Eredevise', 2195),
#  (13, 'Premier League', 3033),
#  (14, 'English Championship', 3978),
#  (16, 'Ligue 1', 2514),
#  (19, 'Bundesliga', 2387),
#  (20, '2. Bundesliga', 2194),
#  (31, 'Serie A', 2726),
#  (53, 'La Liga', 3040),
#  (60, 'English League One', 4401),
#  (68, 'Super Lig', 850)]

# %%
chop = webdriver.ChromeOptions()
chop.add_extension('/home/mace/Downloads/Adblock-Plus_v1.13.3.crx')
driver = webdriver.Chrome('/home/mace/Downloads/chromedriver', chrome_options=chop)
driver2 = webdriver.Chrome('/home/mace/Downloads/chromedriver', chrome_options=chop)

# %%
c.execute('select * from match')
match_cols =[desc[0] for desc in c.description]

# url_base = 'http://de.soccerway.com/national/england/league-one/20162017/regular-season/r36641/matches/?ICID=PL_3N_02'
url_base = 'http://de.soccerway.com/national/england/league-two/20162017/regular-season/r36644/matches/?ICID=PL_3N_02'

# url_base = 'http://de.soccerway.com/national/netherlands/eredivisie/20162017/regular-season/r36385/matches/?ICID=PL_3N_02'

ligaID = 61
odds_data = pd.concat((pd.read_csv(f, dtype={'Date':str, 'AwayTeam':str, 'HomeTeam':str}) for f in csv_files_dict[ligaID]))
odds_data['Date'] = odds_data['Date'].apply(date_conv)
odds_data.rename(columns={'AS':'AShot', 'HS':'HShot', 'BbAv>2.5':'BbAvo25', 'BbAv<2.5':'BbAvu25', 'BbMx>2.5':'BbMxo25', 'BbMx<2.5':'BbMxu25' }, inplace=True)
tm2 = {v[1]:k for k,v in utils.match_club_names([x for x in c.execute('SELECT DISTINCT name, sofifaTeamID FROM team WHERE ligaID=? GROUP BY name', (ligaID,))],list( odds_data['AwayTeam'].dropna().unique())).items()}
driver.get(url_base)
# this can be activated to skip pages in the beginnning
# for _ in range(2):
#     driver.find_element_by_css_selector('.previous').click()
#     time.sleep(0.5)
for select in range(2,10):
    soccerway_teams = []
    while True:
        time.sleep(1.3)
        matches = driver.find_elements_by_css_selector('.score-time.score')
        for match in matches:
            url = match.find_element_by_tag_name('a').get_attribute('href')
            url_ = url.split('/')
            match_dict = dict.fromkeys(match_cols, -1)

            print(url)
            date = datetime(*[int(x) for x in url_[4:7]])
            patch = find_patch_id(date)

            
            
#             TODO select team name by title if errors occur due to incomplete team names
            for teamb in driver.find_elements_by_xpath('//td[@class="team team-b "]/a'):
                soccerway_teams.append(teamb.get_attribute('href').split('/')[5].replace('-', ' '))
            for teamb in driver.find_elements_by_xpath('//td[@class="team team-a "]/a'):
                soccerway_teams.append(teamb.get_attribute('href').split('/')[5].replace('-', ' '))
               
            soccerway_teams = list(set(filter(None,soccerway_teams)))
            if len(soccerway_teams) > 15:
                tm_raw = utils.match_club_names([name for name in c.execute('SELECT name, teamID FROM team WHERE patchID IS '+str(find_patch_id(date))+' AND ligaID IS '+str(ligaID))], soccerway_teams)
                tm = {key:val[1] for key,val in zip(tm_raw.keys(), tm_raw.values())}
            matchID = url_[11]
            #todo map names team_mapping = map_names(stuffstuff)
            homeID, awayID = [tm[x] for x in [' '.join(url_[9].split('-')),' '.join(url_[10].split('-'))]]
            driver2.get(url)
            time.sleep(0.6)
            names = [[],[]]
            
            for p in driver2.find_elements_by_xpath('//div[@class="container left"]//tr'):
                try:
                    jersey = p.find_element_by_class_name('shirtnumber').text
                    name = ' '.join(p.find_element_by_tag_name('a').get_attribute('href').split('/')[4].split('-'))
                    names[0].append((name, jersey))
                except NoSuchElementException:
                    pass
                
            for p in driver2.find_elements_by_xpath('//div[@class="container right"]//tr'):
                try:
                    jersey = p.find_element_by_class_name('shirtnumber').text
                    name = ' '.join(p.find_element_by_tag_name('a').get_attribute('href').split('/')[4].split('-'))
                    names[1].append((name, jersey))
                except NoSuchElementException:
                    pass

            pid = utils.match_player([[x for x in c.execute('SELECT name, playerID, jersey from player WHERE teamID IS ?', (homeID, ))],[x for x in c.execute('SELECT name, playerID, jersey from player WHERE teamID IS ?', (awayID, ))]], names)
            match_dict['patch'] = patch
            match_dict['matchID'] = matchID
            match_dict['date'] = date
            match_dict['ligaID'] = ligaID
            match_dict['homeID'] = homeID
            match_dict['awayID'] = awayID
            match_dict['url'] = url
            #die Daten aus pandas auslesen und ins data_dict uebertragen
            
            game = odds_data[(odds_data['Date']==date) & (odds_data['HomeTeam']== tm2[int(homeID/1000000)]) & (odds_data['AwayTeam']==tm2[int(awayID/1000000)]) ]
            if game.shape[0] == 0:
                continue
            for col in match_cols[42:]:
                if col in game.columns:
                    match_dict[col] = game[col].iloc([0])[0]
            for i, p in enumerate(match_cols[6:42]):
                match_dict[p] = pid[i]

            match_values =  [match_dict[x] for x in match_cols]
            try:
                c.execute('INSERT OR IGNORE INTO match VALUES('+','.join(["?" for x in match_cols ])+')', (*match_values,))
                con.commit()
            except sqlite3.OperationalError:
                print('INSERT OR IGNORE INTO match VALUES('+','.join(["?" for x in match_cols ])+')', (*[match_dict[x] for x in match_cols]))
        print('=============Page Done============')
        try:
            driver.find_element_by_css_selector('.previous.disabled')
            break
        except NoSuchElementException:
            driver.find_element_by_css_selector('.previous').click()

    s = Select(driver.find_element_by_id('season_id_selector'))
    s.select_by_index(select)
    driver.find_elements_by_xpath('//*[@id="submenu"]//li')[1].click()
# Out:
# http://de.soccerway.com/matches/2017/04/22/england/league-two/crewe-alexandra-fc/leyton-orient-fc/2248351/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2017/04/22/england/league-two/wycombe-wanderers-fc/doncaster-rovers-fc/2248359/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2017/04/22/england/league-two/hartlepool-united-fc/barnet-fc/2248354/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2017/04/22/england/league-two/exeter-city-fc/morecambe-fc/2248352/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2017/04/22/england/league-two/newport-county-afc/accrington-stanley-fc/2248356/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2017/04/22/england/league-two/crawley-town-football-club/carlisle-united-fc/2248350/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2017/04/29/england/league-two/cambridge-united-fc/crawley-town-football-club/2248362/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2017/04/29/england/league-two/barnet-fc/grimsby-town-fc/2248361/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2017/04/29/england/league-two/accrington-stanley-fc/luton-town-fc/2248360/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2017/04/29/england/league-two/morecambe-fc/wycombe-wanderers-fc/2248368/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2017/04/29/england/league-two/doncaster-rovers-fc/exeter-city-fc/2248365/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2017/04/29/england/league-two/cheltenham-town-fc/hartlepool-united-fc/2248364/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2017/04/29/england/league-two/leyton-orient-fc/colchester-united-fc/2248366/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2017/04/29/england/league-two/carlisle-united-fc/newport-county-afc/2248363/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2017/04/29/england/league-two/yeovil-town-fc/stevenage-borough-fc/2248371/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2017/04/29/england/league-two/notts-county-fc/blackpool-fc/2248369/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2017/04/29/england/league-two/plymouth-argyle-fc/crewe-alexandra-fc/2248370/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2017/04/29/england/league-two/mansfield-town-fc/portsmouth-football-club/2248367/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2017/05/06/england/league-two/blackpool-fc/leyton-orient-fc/2248372/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2017/05/06/england/league-two/hartlepool-united-fc/doncaster-rovers-fc/2248378/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2017/05/06/england/league-two/exeter-city-fc/carlisle-united-fc/2248376/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2017/05/06/england/league-two/colchester-united-fc/yeovil-town-fc/2248373/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2017/05/06/england/league-two/crawley-town-football-club/mansfield-town-fc/2248374/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2017/05/06/england/league-two/crewe-alexandra-fc/barnet-fc/2248375/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2017/05/06/england/league-two/newport-county-afc/notts-county-fc/2248380/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2017/05/06/england/league-two/grimsby-town-fc/plymouth-argyle-fc/2248377/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2017/05/06/england/league-two/luton-town-fc/morecambe-fc/2248379/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2017/05/06/england/league-two/stevenage-borough-fc/accrington-stanley-fc/2248382/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2017/05/06/england/league-two/wycombe-wanderers-fc/cambridge-united-fc/2248383/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2017/05/06/england/league-two/portsmouth-football-club/cheltenham-town-fc/2248381/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2017/04/14/england/league-two/portsmouth-football-club/plymouth-argyle-fc/2248333/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2017/04/14/england/league-two/wycombe-wanderers-fc/mansfield-town-fc/2248335/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2017/04/14/england/league-two/stevenage-borough-fc/morecambe-fc/2248334/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2017/04/14/england/league-two/newport-county-afc/yeovil-town-fc/2248332/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2017/04/14/england/league-two/luton-town-fc/leyton-orient-fc/2248331/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2017/04/14/england/league-two/hartlepool-united-fc/carlisle-united-fc/2248330/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2017/04/14/england/league-two/grimsby-town-fc/cambridge-united-fc/2248329/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2017/04/14/england/league-two/exeter-city-fc/barnet-fc/2248328/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2017/04/14/england/league-two/crewe-alexandra-fc/notts-county-fc/2248327/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2017/04/14/england/league-two/crawley-town-football-club/cheltenham-town-fc/2248326/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2017/04/14/england/league-two/colchester-united-fc/doncaster-rovers-fc/2248325/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2017/04/14/england/league-two/blackpool-fc/accrington-stanley-fc/2248324/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2017/04/17/england/league-two/cheltenham-town-fc/grimsby-town-fc/2248340/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2017/04/17/england/league-two/yeovil-town-fc/crewe-alexandra-fc/2248347/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2017/04/17/england/league-two/plymouth-argyle-fc/newport-county-afc/2248346/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2017/04/17/england/league-two/notts-county-fc/portsmouth-football-club/2248345/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2017/04/17/england/league-two/morecambe-fc/colchester-united-fc/2248344/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2017/04/17/england/league-two/mansfield-town-fc/luton-town-fc/2248343/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2017/04/17/england/league-two/leyton-orient-fc/hartlepool-united-fc/2248342/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2017/04/17/england/league-two/doncaster-rovers-fc/blackpool-fc/2248341/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2017/04/17/england/league-two/carlisle-united-fc/stevenage-borough-fc/2248339/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2017/04/17/england/league-two/cambridge-united-fc/exeter-city-fc/2248338/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2017/04/17/england/league-two/barnet-fc/wycombe-wanderers-fc/2248337/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2017/04/17/england/league-two/accrington-stanley-fc/crawley-town-football-club/2248336/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2017/04/22/england/league-two/stevenage-borough-fc/mansfield-town-fc/2248358/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2017/04/22/england/league-two/portsmouth-football-club/cambridge-united-fc/2248357/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2017/04/22/england/league-two/crewe-alexandra-fc/leyton-orient-fc/2248351/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2017/04/22/england/league-two/crawley-town-football-club/carlisle-united-fc/2248350/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2017/04/22/england/league-two/colchester-united-fc/plymouth-argyle-fc/2248349/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2017/04/22/england/league-two/blackpool-fc/cheltenham-town-fc/2248348/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2017/03/25/england/league-two/cambridge-united-fc/stevenage-borough-fc/2248291/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2017/03/25/england/league-two/blackpool-fc/hartlepool-united-fc/2248290/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2017/03/25/england/league-two/barnet-fc/cheltenham-town-fc/2248289/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2017/03/25/england/league-two/accrington-stanley-fc/grimsby-town-fc/2248288/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2017/03/26/england/league-two/doncaster-rovers-fc/plymouth-argyle-fc/2248295/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2017/03/28/england/league-two/accrington-stanley-fc/cambridge-united-fc/2248120/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2017/04/01/england/league-two/grimsby-town-fc/doncaster-rovers-fc/2248302/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2017/04/01/england/league-two/yeovil-town-fc/carlisle-united-fc/2248311/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2017/04/01/england/league-two/stevenage-borough-fc/barnet-fc/2248310/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2017/04/01/england/league-two/plymouth-argyle-fc/accrington-stanley-fc/2248309/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2017/04/01/england/league-two/notts-county-fc/colchester-united-fc/2248308/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2017/04/01/england/league-two/newport-county-afc/crawley-town-football-club/2248307/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2017/04/01/england/league-two/mansfield-town-fc/exeter-city-fc/2248306/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2017/04/01/england/league-two/luton-town-fc/blackpool-fc/2248305/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2017/04/01/england/league-two/leyton-orient-fc/wycombe-wanderers-fc/2248304/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2017/04/01/england/league-two/hartlepool-united-fc/portsmouth-football-club/2248303/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2017/04/01/england/league-two/crewe-alexandra-fc/cambridge-united-fc/2248301/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2017/04/01/england/league-two/cheltenham-town-fc/morecambe-fc/2248300/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2017/04/08/england/league-two/wycombe-wanderers-fc/cheltenham-town-fc/2248323/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2017/04/08/england/league-two/portsmouth-football-club/yeovil-town-fc/2248322/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2017/04/08/england/league-two/morecambe-fc/hartlepool-united-fc/2248321/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2017/04/08/england/league-two/doncaster-rovers-fc/mansfield-town-fc/2248319/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2017/04/08/england/league-two/crawley-town-football-club/plymouth-argyle-fc/2248318/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2017/04/08/england/league-two/colchester-united-fc/stevenage-borough-fc/2248317/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2017/04/08/england/league-two/carlisle-united-fc/notts-county-fc/2248316/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2017/04/08/england/league-two/cambridge-united-fc/leyton-orient-fc/2248315/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2017/04/08/england/league-two/blackpool-fc/grimsby-town-fc/2248314/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2017/04/08/england/league-two/barnet-fc/luton-town-fc/2248313/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2017/04/08/england/league-two/accrington-stanley-fc/crewe-alexandra-fc/2248312/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2017/04/08/england/league-two/exeter-city-fc/newport-county-afc/2248320/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2017/03/14/england/league-two/exeter-city-fc/cheltenham-town-fc/2248272/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2017/03/14/england/league-two/doncaster-rovers-fc/notts-county-fc/2248271/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2017/03/14/england/league-two/crawley-town-football-club/crewe-alexandra-fc/2248270/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2017/03/14/england/league-two/colchester-united-fc/mansfield-town-fc/2248269/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2017/03/14/england/league-two/carlisle-united-fc/luton-town-fc/2248268/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2017/03/14/england/league-two/cambridge-united-fc/hartlepool-united-fc/2248267/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2017/03/14/england/league-two/blackpool-fc/stevenage-borough-fc/2248266/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2017/03/14/england/league-two/accrington-stanley-fc/leyton-orient-fc/2248264/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2017/03/15/england/league-two/barnet-fc/yeovil-town-fc/2248265/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2017/03/18/england/league-two/yeovil-town-fc/accrington-stanley-fc/2248287/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2017/03/18/england/league-two/stevenage-borough-fc/portsmouth-football-club/2248286/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2017/03/18/england/league-two/plymouth-argyle-fc/morecambe-fc/2248285/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2017/03/18/england/league-two/newport-county-afc/blackpool-fc/2248283/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2017/03/18/england/league-two/mansfield-town-fc/carlisle-united-fc/2248282/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2017/03/18/england/league-two/luton-town-fc/exeter-city-fc/2248281/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2017/03/18/england/league-two/leyton-orient-fc/doncaster-rovers-fc/2248280/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2017/03/18/england/league-two/hartlepool-united-fc/wycombe-wanderers-fc/2248279/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2017/03/18/england/league-two/grimsby-town-fc/crawley-town-football-club/2248278/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2017/03/18/england/league-two/cheltenham-town-fc/cambridge-united-fc/2248276/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2017/03/18/england/league-two/crewe-alexandra-fc/colchester-united-fc/2248277/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2017/03/19/england/league-two/notts-county-fc/barnet-fc/2248284/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2017/03/21/england/league-two/newport-county-afc/luton-town-fc/2248235/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2017/03/21/england/league-two/morecambe-fc/accrington-stanley-fc/2248161/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2017/03/25/england/league-two/wycombe-wanderers-fc/notts-county-fc/2248299/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2017/03/25/england/league-two/portsmouth-football-club/newport-county-afc/2248298/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2017/03/25/england/league-two/morecambe-fc/mansfield-town-fc/2248297/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2017/03/25/england/league-two/exeter-city-fc/yeovil-town-fc/2248296/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2017/03/25/england/league-two/crawley-town-football-club/leyton-orient-fc/2248294/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2017/03/25/england/league-two/colchester-united-fc/luton-town-fc/2248293/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2017/03/25/england/league-two/carlisle-united-fc/crewe-alexandra-fc/2248292/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2017/02/28/england/league-two/accrington-stanley-fc/wycombe-wanderers-fc/2248228/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2017/03/04/england/league-two/yeovil-town-fc/luton-town-fc/2248251/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2017/03/04/england/league-two/stevenage-borough-fc/notts-county-fc/2248250/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2017/03/04/england/league-two/portsmouth-football-club/crewe-alexandra-fc/2248249/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2017/03/04/england/league-two/plymouth-argyle-fc/carlisle-united-fc/2248248/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2017/03/04/england/league-two/newport-county-afc/leyton-orient-fc/2248247/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2017/03/04/england/league-two/hartlepool-united-fc/exeter-city-fc/2248246/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2017/03/04/england/league-two/grimsby-town-fc/wycombe-wanderers-fc/2248245/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2017/03/04/england/league-two/crawley-town-football-club/doncaster-rovers-fc/2248244/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2017/03/04/england/league-two/cheltenham-town-fc/mansfield-town-fc/2248243/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2017/03/04/england/league-two/cambridge-united-fc/colchester-united-fc/2248242/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2017/03/04/england/league-two/blackpool-fc/morecambe-fc/2248241/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2017/03/04/england/league-two/accrington-stanley-fc/barnet-fc/2248240/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2017/03/07/england/league-two/plymouth-argyle-fc/blackpool-fc/2248164/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2017/03/07/england/league-two/crawley-town-football-club/portsmouth-football-club/2248149/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2017/03/11/england/league-two/wycombe-wanderers-fc/blackpool-fc/2248263/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2017/03/11/england/league-two/notts-county-fc/hartlepool-united-fc/2248262/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2017/03/11/england/league-two/morecambe-fc/yeovil-town-fc/2248261/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2017/03/11/england/league-two/mansfield-town-fc/plymouth-argyle-fc/2248260/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2017/03/11/england/league-two/luton-town-fc/stevenage-borough-fc/2248259/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2017/03/11/england/league-two/leyton-orient-fc/grimsby-town-fc/2248258/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2017/03/11/england/league-two/exeter-city-fc/accrington-stanley-fc/2248257/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2017/03/11/england/league-two/doncaster-rovers-fc/cheltenham-town-fc/2248256/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2017/03/11/england/league-two/crewe-alexandra-fc/newport-county-afc/2248255/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2017/03/11/england/league-two/colchester-united-fc/portsmouth-football-club/2248254/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2017/03/11/england/league-two/carlisle-united-fc/cambridge-united-fc/2248253/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2017/03/11/england/league-two/barnet-fc/crawley-town-football-club/2248252/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2017/03/14/england/league-two/wycombe-wanderers-fc/plymouth-argyle-fc/2248275/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2017/03/14/england/league-two/portsmouth-football-club/grimsby-town-fc/2248274/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2017/03/14/england/league-two/morecambe-fc/newport-county-afc/2248273/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2017/02/18/england/league-two/crawley-town-football-club/morecambe-fc/2248209/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2017/02/18/england/league-two/cheltenham-town-fc/yeovil-town-fc/2248208/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2017/02/18/england/league-two/cambridge-united-fc/newport-county-afc/2248207/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2017/02/18/england/league-two/blackpool-fc/crewe-alexandra-fc/2248206/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2017/02/18/england/league-two/barnet-fc/portsmouth-football-club/2248205/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2017/02/18/england/league-two/accrington-stanley-fc/colchester-united-fc/2248204/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2017/02/21/england/league-two/colchester-united-fc/wycombe-wanderers-fc/2248157/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2017/02/21/england/league-two/newport-county-afc/morecambe-fc/2248067/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2017/02/25/england/league-two/wycombe-wanderers-fc/crawley-town-football-club/2248227/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2017/02/25/england/league-two/notts-county-fc/yeovil-town-fc/2248226/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2017/02/25/england/league-two/morecambe-fc/grimsby-town-fc/2248225/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2017/02/25/england/league-two/mansfield-town-fc/newport-county-afc/2248224/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2017/02/25/england/league-two/luton-town-fc/plymouth-argyle-fc/2248223/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2017/02/25/england/league-two/leyton-orient-fc/cheltenham-town-fc/2248222/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2017/02/25/england/league-two/exeter-city-fc/blackpool-fc/2248221/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2017/02/25/england/league-two/doncaster-rovers-fc/accrington-stanley-fc/2248220/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2017/02/25/england/league-two/crewe-alexandra-fc/stevenage-borough-fc/2248219/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2017/02/25/england/league-two/colchester-united-fc/hartlepool-united-fc/2248218/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2017/02/25/england/league-two/carlisle-united-fc/portsmouth-football-club/2248217/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2017/02/25/england/league-two/barnet-fc/cambridge-united-fc/2248216/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2017/02/28/england/league-two/yeovil-town-fc/mansfield-town-fc/2248239/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2017/02/28/england/league-two/stevenage-borough-fc/leyton-orient-fc/2248238/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2017/02/28/england/league-two/portsmouth-football-club/morecambe-fc/2248237/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2017/02/28/england/league-two/plymouth-argyle-fc/notts-county-fc/2248236/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2017/02/28/england/league-two/hartlepool-united-fc/crewe-alexandra-fc/2248234/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2017/02/28/england/league-two/grimsby-town-fc/colchester-united-fc/2248233/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2017/02/28/england/league-two/crawley-town-football-club/exeter-city-fc/2248232/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2017/02/28/england/league-two/cheltenham-town-fc/carlisle-united-fc/2248231/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2017/02/28/england/league-two/cambridge-united-fc/doncaster-rovers-fc/2248230/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2017/02/28/england/league-two/blackpool-fc/barnet-fc/2248229/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2017/02/10/england/league-two/newport-county-afc/doncaster-rovers-fc/2248186/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2017/02/11/england/league-two/yeovil-town-fc/leyton-orient-fc/2248191/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2017/02/11/england/league-two/stevenage-borough-fc/wycombe-wanderers-fc/2248190/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2017/02/11/england/league-two/portsmouth-football-club/accrington-stanley-fc/2248189/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2017/02/11/england/league-two/plymouth-argyle-fc/exeter-city-fc/2248188/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2017/02/11/england/league-two/notts-county-fc/cheltenham-town-fc/2248187/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2017/02/11/england/league-two/morecambe-fc/cambridge-united-fc/2248185/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2017/02/11/england/league-two/mansfield-town-fc/hartlepool-united-fc/2248184/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2017/02/11/england/league-two/luton-town-fc/crawley-town-football-club/2248183/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2017/02/11/england/league-two/crewe-alexandra-fc/grimsby-town-fc/2248182/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2017/02/11/england/league-two/colchester-united-fc/barnet-fc/2248181/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2017/02/11/england/league-two/carlisle-united-fc/blackpool-fc/2248180/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2017/02/14/england/league-two/yeovil-town-fc/cambridge-united-fc/2248203/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2017/02/14/england/league-two/stevenage-borough-fc/cheltenham-town-fc/2248202/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2017/02/14/england/league-two/portsmouth-football-club/blackpool-fc/2248201/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2017/02/14/england/league-two/plymouth-argyle-fc/leyton-orient-fc/2248200/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2017/02/14/england/league-two/notts-county-fc/exeter-city-fc/2248199/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2017/02/14/england/league-two/newport-county-afc/grimsby-town-fc/2248198/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2017/02/14/england/league-two/morecambe-fc/barnet-fc/2248197/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2017/02/14/england/league-two/mansfield-town-fc/accrington-stanley-fc/2248196/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2017/02/14/england/league-two/luton-town-fc/hartlepool-united-fc/2248195/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2017/02/14/england/league-two/crewe-alexandra-fc/wycombe-wanderers-fc/2248194/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2017/02/14/england/league-two/colchester-united-fc/crawley-town-football-club/2248193/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2017/02/14/england/league-two/carlisle-united-fc/doncaster-rovers-fc/2248192/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2017/02/18/england/league-two/wycombe-wanderers-fc/carlisle-united-fc/2248215/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2017/02/18/england/league-two/leyton-orient-fc/notts-county-fc/2248214/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2017/02/18/england/league-two/hartlepool-united-fc/plymouth-argyle-fc/2248213/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2017/02/18/england/league-two/grimsby-town-fc/mansfield-town-fc/2248212/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2017/02/18/england/league-two/exeter-city-fc/stevenage-borough-fc/2248211/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2017/02/18/england/league-two/doncaster-rovers-fc/luton-town-fc/2248210/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2017/01/21/england/league-two/cambridge-united-fc/mansfield-town-fc/2248147/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2017/01/21/england/league-two/blackpool-fc/yeovil-town-fc/2248146/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2017/01/21/england/league-two/barnet-fc/newport-county-afc/2248145/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2017/01/21/england/league-two/accrington-stanley-fc/carlisle-united-fc/2248144/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2017/01/28/england/league-two/yeovil-town-fc/doncaster-rovers-fc/2248167/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2017/01/28/england/league-two/stevenage-borough-fc/grimsby-town-fc/2248166/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2017/01/28/england/league-two/portsmouth-football-club/exeter-city-fc/2248165/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2017/01/28/england/league-two/notts-county-fc/crawley-town-football-club/2248163/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2017/01/28/england/league-two/newport-county-afc/hartlepool-united-fc/2248162/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2017/01/28/england/league-two/mansfield-town-fc/leyton-orient-fc/2248160/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2017/01/28/england/league-two/luton-town-fc/cambridge-united-fc/2248159/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2017/01/28/england/league-two/crewe-alexandra-fc/cheltenham-town-fc/2248158/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2017/01/28/england/league-two/carlisle-united-fc/barnet-fc/2248156/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2017/01/31/england/league-two/yeovil-town-fc/plymouth-argyle-fc/2248131/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2017/01/31/england/league-two/luton-town-fc/cheltenham-town-fc/2248127/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2017/01/31/england/league-two/exeter-city-fc/wycombe-wanderers-fc/2248124/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2017/02/04/england/league-two/wycombe-wanderers-fc/portsmouth-football-club/2248179/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2017/02/04/england/league-two/leyton-orient-fc/carlisle-united-fc/2248178/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2017/02/04/england/league-two/hartlepool-united-fc/yeovil-town-fc/2248177/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2017/02/04/england/league-two/grimsby-town-fc/luton-town-fc/2248176/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2017/02/04/england/league-two/exeter-city-fc/crewe-alexandra-fc/2248175/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2017/02/04/england/league-two/doncaster-rovers-fc/morecambe-fc/2248174/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2017/02/04/england/league-two/crawley-town-football-club/stevenage-borough-fc/2248173/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2017/02/04/england/league-two/cheltenham-town-fc/newport-county-afc/2248172/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2017/02/04/england/league-two/cambridge-united-fc/plymouth-argyle-fc/2248171/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2017/02/04/england/league-two/blackpool-fc/colchester-united-fc/2248170/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2017/02/04/england/league-two/barnet-fc/mansfield-town-fc/2248169/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2017/02/04/england/league-two/accrington-stanley-fc/notts-county-fc/2248168/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2017/02/07/england/league-two/leyton-orient-fc/morecambe-fc/2248154/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2017/02/07/england/league-two/blackpool-fc/crawley-town-football-club/2248121/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2017/01/02/england/league-two/carlisle-united-fc/grimsby-town-fc/2248112/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2017/01/02/england/league-two/cambridge-united-fc/notts-county-fc/2248111/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2017/01/02/england/league-two/blackpool-fc/mansfield-town-fc/2248110/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2017/01/02/england/league-two/barnet-fc/plymouth-argyle-fc/2248109/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2017/01/02/england/league-two/accrington-stanley-fc/hartlepool-united-fc/2248108/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2017/01/05/england/league-two/doncaster-rovers-fc/portsmouth-football-club/2248123/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2017/01/07/england/league-two/stevenage-borough-fc/newport-county-afc/2248130/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2017/01/07/england/league-two/morecambe-fc/notts-county-fc/2248129/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2017/01/07/england/league-two/mansfield-town-fc/crewe-alexandra-fc/2248128/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2017/01/07/england/league-two/leyton-orient-fc/barnet-fc/2248126/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2017/01/07/england/league-two/hartlepool-united-fc/grimsby-town-fc/2248125/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2017/01/07/england/league-two/colchester-united-fc/carlisle-united-fc/2248122/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2017/01/14/england/league-two/notts-county-fc/mansfield-town-fc/2248140/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2017/01/14/england/league-two/wycombe-wanderers-fc/yeovil-town-fc/2248143/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2017/01/14/england/league-two/portsmouth-football-club/leyton-orient-fc/2248142/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2017/01/14/england/league-two/plymouth-argyle-fc/stevenage-borough-fc/2248141/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2017/01/14/england/league-two/newport-county-afc/colchester-united-fc/2248139/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2017/01/14/england/league-two/grimsby-town-fc/exeter-city-fc/2248138/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2017/01/14/england/league-two/crewe-alexandra-fc/luton-town-fc/2248137/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2017/01/14/england/league-two/crawley-town-football-club/hartlepool-united-fc/2248136/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2017/01/14/england/league-two/cheltenham-town-fc/accrington-stanley-fc/2248135/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2017/01/14/england/league-two/carlisle-united-fc/morecambe-fc/2248134/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2017/01/14/england/league-two/cambridge-united-fc/blackpool-fc/2248133/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2017/01/14/england/league-two/barnet-fc/doncaster-rovers-fc/2248132/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2017/01/21/england/league-two/wycombe-wanderers-fc/luton-town-fc/2248155/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2017/01/21/england/league-two/hartlepool-united-fc/stevenage-borough-fc/2248153/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2017/01/21/england/league-two/grimsby-town-fc/notts-county-fc/2248152/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2017/01/21/england/league-two/exeter-city-fc/colchester-united-fc/2248151/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2017/01/21/england/league-two/doncaster-rovers-fc/crewe-alexandra-fc/2248150/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2017/01/21/england/league-two/cheltenham-town-fc/plymouth-argyle-fc/2248148/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2016/12/26/england/league-two/yeovil-town-fc/exeter-city-fc/2248095/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2016/12/26/england/league-two/stevenage-borough-fc/cambridge-united-fc/2248094/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2016/12/26/england/league-two/plymouth-argyle-fc/wycombe-wanderers-fc/2248093/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2016/12/26/england/league-two/notts-county-fc/doncaster-rovers-fc/2248092/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2016/12/26/england/league-two/newport-county-afc/portsmouth-football-club/2248091/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2016/12/26/england/league-two/mansfield-town-fc/morecambe-fc/2248090/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2016/12/26/england/league-two/luton-town-fc/colchester-united-fc/2248089/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2016/12/26/england/league-two/hartlepool-united-fc/blackpool-fc/2248087/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2016/12/26/england/league-two/grimsby-town-fc/accrington-stanley-fc/2248086/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2016/12/26/england/league-two/crewe-alexandra-fc/carlisle-united-fc/2248085/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2016/12/26/england/league-two/cheltenham-town-fc/barnet-fc/2248084/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2016/12/30/england/league-two/yeovil-town-fc/portsmouth-football-club/2248107/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2016/12/30/england/league-two/hartlepool-united-fc/morecambe-fc/2248099/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2016/12/30/england/league-two/cheltenham-town-fc/wycombe-wanderers-fc/2248096/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2016/12/31/england/league-two/mansfield-town-fc/doncaster-rovers-fc/2248102/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2016/12/31/england/league-two/leyton-orient-fc/cambridge-united-fc/2248100/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2016/12/31/england/league-two/stevenage-borough-fc/colchester-united-fc/2248106/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2016/12/31/england/league-two/plymouth-argyle-fc/crawley-town-football-club/2248105/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2016/12/31/england/league-two/notts-county-fc/carlisle-united-fc/2248104/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2016/12/31/england/league-two/newport-county-afc/exeter-city-fc/2248103/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2016/12/31/england/league-two/luton-town-fc/barnet-fc/2248101/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2016/12/31/england/league-two/grimsby-town-fc/blackpool-fc/2248098/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2016/12/31/england/league-two/crewe-alexandra-fc/accrington-stanley-fc/2248097/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2017/01/02/england/league-two/wycombe-wanderers-fc/newport-county-afc/2248119/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2017/01/02/england/league-two/portsmouth-football-club/luton-town-fc/2248118/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2017/01/02/england/league-two/morecambe-fc/crewe-alexandra-fc/2248117/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2017/01/02/england/league-two/exeter-city-fc/leyton-orient-fc/2248116/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2017/01/02/england/league-two/doncaster-rovers-fc/stevenage-borough-fc/2248115/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2017/01/02/england/league-two/crawley-town-football-club/yeovil-town-fc/2248114/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2017/01/02/england/league-two/colchester-united-fc/cheltenham-town-fc/2248113/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2016/11/26/england/league-two/blackpool-fc/newport-county-afc/2248050/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2016/11/26/england/league-two/barnet-fc/notts-county-fc/2248049/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2016/11/26/england/league-two/accrington-stanley-fc/yeovil-town-fc/2248048/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2016/12/03/england/league-two/yeovil-town-fc/crawley-town-football-club/2248047/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2016/12/03/england/league-two/stevenage-borough-fc/doncaster-rovers-fc/2248046/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2016/12/06/england/league-two/newport-county-afc/stevenage-borough-fc/2247959/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2016/12/10/england/league-two/yeovil-town-fc/barnet-fc/2248071/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2016/12/10/england/league-two/stevenage-borough-fc/blackpool-fc/2248070/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2016/12/10/england/league-two/plymouth-argyle-fc/doncaster-rovers-fc/2248069/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2016/12/10/england/league-two/notts-county-fc/wycombe-wanderers-fc/2248068/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2016/12/10/england/league-two/mansfield-town-fc/colchester-united-fc/2248066/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2016/12/10/england/league-two/luton-town-fc/carlisle-united-fc/2248065/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2016/12/10/england/league-two/leyton-orient-fc/accrington-stanley-fc/2248064/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2016/12/10/england/league-two/hartlepool-united-fc/cambridge-united-fc/2248063/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2016/12/10/england/league-two/grimsby-town-fc/portsmouth-football-club/2248062/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2016/12/10/england/league-two/crewe-alexandra-fc/crawley-town-football-club/2248061/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2016/12/10/england/league-two/cheltenham-town-fc/exeter-city-fc/2248060/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2016/12/17/england/league-two/doncaster-rovers-fc/grimsby-town-fc/2248079/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2016/12/17/england/league-two/wycombe-wanderers-fc/leyton-orient-fc/2248083/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2016/12/17/england/league-two/portsmouth-football-club/hartlepool-united-fc/2248082/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2016/12/17/england/league-two/morecambe-fc/cheltenham-town-fc/2248081/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2016/12/17/england/league-two/exeter-city-fc/mansfield-town-fc/2248080/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2016/12/17/england/league-two/crawley-town-football-club/newport-county-afc/2248078/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2016/12/17/england/league-two/colchester-united-fc/notts-county-fc/2248077/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2016/12/17/england/league-two/carlisle-united-fc/yeovil-town-fc/2248076/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2016/12/17/england/league-two/cambridge-united-fc/crewe-alexandra-fc/2248075/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2016/12/17/england/league-two/blackpool-fc/luton-town-fc/2248074/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2016/12/17/england/league-two/barnet-fc/stevenage-borough-fc/2248073/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2016/12/17/england/league-two/accrington-stanley-fc/plymouth-argyle-fc/2248072/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2016/12/26/england/league-two/leyton-orient-fc/crawley-town-football-club/2248088/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2016/11/19/england/league-two/plymouth-argyle-fc/grimsby-town-fc/2248034/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2016/11/19/england/league-two/notts-county-fc/newport-county-afc/2248033/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2016/11/19/england/league-two/morecambe-fc/luton-town-fc/2248032/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2016/11/19/england/league-two/mansfield-town-fc/crawley-town-football-club/2248031/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2016/11/19/england/league-two/leyton-orient-fc/blackpool-fc/2248030/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2016/11/19/england/league-two/doncaster-rovers-fc/hartlepool-united-fc/2248029/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2016/11/19/england/league-two/cheltenham-town-fc/portsmouth-football-club/2248028/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2016/11/19/england/league-two/carlisle-united-fc/exeter-city-fc/2248027/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2016/11/19/england/league-two/cambridge-united-fc/wycombe-wanderers-fc/2248026/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2016/11/19/england/league-two/barnet-fc/crewe-alexandra-fc/2248025/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2016/11/19/england/league-two/accrington-stanley-fc/stevenage-borough-fc/2248024/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2016/11/22/england/league-two/plymouth-argyle-fc/barnet-fc/2248045/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2016/11/22/england/league-two/notts-county-fc/cambridge-united-fc/2248044/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2016/11/22/england/league-two/newport-county-afc/wycombe-wanderers-fc/2248043/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2016/11/22/england/league-two/mansfield-town-fc/blackpool-fc/2248042/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2016/11/22/england/league-two/luton-town-fc/portsmouth-football-club/2248041/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2016/11/22/england/league-two/leyton-orient-fc/exeter-city-fc/2248040/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2016/11/22/england/league-two/hartlepool-united-fc/accrington-stanley-fc/2248039/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2016/11/22/england/league-two/grimsby-town-fc/carlisle-united-fc/2248038/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2016/11/22/england/league-two/crewe-alexandra-fc/morecambe-fc/2248037/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2016/11/22/england/league-two/cheltenham-town-fc/colchester-united-fc/2248036/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2016/11/26/england/league-two/wycombe-wanderers-fc/hartlepool-united-fc/2248059/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2016/11/26/england/league-two/portsmouth-football-club/stevenage-borough-fc/2248058/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2016/11/26/england/league-two/morecambe-fc/plymouth-argyle-fc/2248057/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2016/11/26/england/league-two/exeter-city-fc/luton-town-fc/2248056/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2016/11/26/england/league-two/doncaster-rovers-fc/leyton-orient-fc/2248055/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2016/11/26/england/league-two/crawley-town-football-club/grimsby-town-fc/2248054/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2016/11/26/england/league-two/colchester-united-fc/crewe-alexandra-fc/2248053/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2016/11/26/england/league-two/carlisle-united-fc/mansfield-town-fc/2248052/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2016/11/26/england/league-two/cambridge-united-fc/cheltenham-town-fc/2248051/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2016/10/22/england/league-two/crewe-alexandra-fc/yeovil-town-fc/2247991/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2016/10/22/england/league-two/crawley-town-football-club/accrington-stanley-fc/2247990/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2016/10/22/england/league-two/colchester-united-fc/morecambe-fc/2247989/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2016/10/22/england/league-two/blackpool-fc/doncaster-rovers-fc/2247988/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2016/10/25/england/league-two/newport-county-afc/barnet-fc/2247898/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2016/10/29/england/league-two/yeovil-town-fc/grimsby-town-fc/2248011/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2016/10/29/england/league-two/plymouth-argyle-fc/colchester-united-fc/2248010/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2016/10/29/england/league-two/notts-county-fc/luton-town-fc/2248009/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2016/10/29/england/league-two/morecambe-fc/exeter-city-fc/2248008/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2016/10/29/england/league-two/mansfield-town-fc/stevenage-borough-fc/2248007/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2016/10/29/england/league-two/leyton-orient-fc/crewe-alexandra-fc/2248006/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2016/10/29/england/league-two/doncaster-rovers-fc/wycombe-wanderers-fc/2248005/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2016/10/29/england/league-two/cheltenham-town-fc/blackpool-fc/2248004/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2016/10/29/england/league-two/carlisle-united-fc/crawley-town-football-club/2248003/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2016/10/29/england/league-two/cambridge-united-fc/portsmouth-football-club/2248002/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2016/10/29/england/league-two/barnet-fc/hartlepool-united-fc/2248001/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2016/10/29/england/league-two/accrington-stanley-fc/newport-county-afc/2248000/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2016/11/12/england/league-two/newport-county-afc/carlisle-united-fc/2248020/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2016/11/12/england/league-two/wycombe-wanderers-fc/morecambe-fc/2248023/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2016/11/12/england/league-two/stevenage-borough-fc/yeovil-town-fc/2248022/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2016/11/12/england/league-two/portsmouth-football-club/mansfield-town-fc/2248021/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2016/11/12/england/league-two/luton-town-fc/accrington-stanley-fc/2248019/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2016/11/12/england/league-two/hartlepool-united-fc/cheltenham-town-fc/2248018/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2016/11/12/england/league-two/grimsby-town-fc/barnet-fc/2248017/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2016/11/12/england/league-two/exeter-city-fc/doncaster-rovers-fc/2248016/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2016/11/12/england/league-two/crewe-alexandra-fc/plymouth-argyle-fc/2248015/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2016/11/12/england/league-two/crawley-town-football-club/cambridge-united-fc/2248014/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2016/11/12/england/league-two/colchester-united-fc/leyton-orient-fc/2248013/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2016/11/12/england/league-two/blackpool-fc/notts-county-fc/2248012/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2016/11/19/england/league-two/yeovil-town-fc/colchester-united-fc/2248035/?ICID=PL_MS_30
# =============Page Done============
# ...
# http://de.soccerway.com/matches/2012/02/18/england/league-two/bristol-rovers-fc/oxford-united-fc/1119462/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2012/02/18/england/league-two/macclesfield-town-fc/aldershot-town-fc/1119461/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2012/02/18/england/league-two/burton-albion-fc/rotherham-united-fc/1119460/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2012/02/18/england/league-two/hereford-united-fc/swindon-town-fc/1119459/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2012/02/18/england/league-two/southend-united-fc/crewe-alexandra-fc/1119458/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2012/02/18/england/league-two/accrington-stanley-fc/plymouth-argyle-fc/1119457/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2012/02/18/england/league-two/dagenham--redbridge-fc/cheltenham-town-fc/1119456/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2012/02/18/england/league-two/torquay-united-fc/bradford-city-afc/1119455/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2012/02/18/england/league-two/barnet-fc/shrewsbury-town-fc/1119454/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2012/02/18/england/league-two/afc-wimbledon/morecambe-fc/1119453/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2012/02/21/england/league-two/oxford-united-fc/barnet-fc/1119426/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2012/02/21/england/league-two/cheltenham-town-fc/afc-wimbledon/1119421/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2012/02/21/england/league-two/northampton-town-fc/macclesfield-town-fc/1119420/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2012/02/21/england/league-two/crewe-alexandra-fc/accrington-stanley-fc/1119417/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2012/02/21/england/league-two/swindon-town-fc/shrewsbury-town-fc/1119378/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2012/02/21/england/league-two/gillingham-fc/rotherham-united-fc/1119376/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2012/02/21/england/league-two/aldershot-town-fc/southend-united-fc/1119333/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2012/02/22/england/league-two/crawley-town-football-club/morecambe-fc/1119405/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2012/02/25/england/league-two/swindon-town-fc/accrington-stanley-fc/1119475/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2012/02/25/england/league-two/plymouth-argyle-fc/dagenham--redbridge-fc/1119474/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2012/02/25/england/league-two/bradford-city-afc/hereford-united-fc/1119473/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2012/02/25/england/league-two/cheltenham-town-fc/burton-albion-fc/1119472/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2012/02/25/england/league-two/aldershot-town-fc/barnet-fc/1119471/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2012/01/21/england/league-two/cheltenham-town-fc/bristol-rovers-fc/1119397/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2012/01/21/england/league-two/shrewsbury-town-fc/southend-united-fc/1119396/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2012/01/21/england/league-two/plymouth-argyle-fc/crawley-town-football-club/1119395/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2012/01/21/england/league-two/bradford-city-afc/burton-albion-fc/1119394/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2012/01/21/england/league-two/rotherham-united-fc/port-vale-fc/1119393/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2012/01/24/england/league-two/torquay-united-fc/dagenham--redbridge-fc/1119380/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2012/01/24/england/league-two/afc-wimbledon/macclesfield-town-fc/1119373/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2012/01/28/england/league-two/hereford-united-fc/shrewsbury-town-fc/1119407/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2012/01/28/england/league-two/port-vale-fc/plymouth-argyle-fc/1119416/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2012/01/28/england/league-two/macclesfield-town-fc/cheltenham-town-fc/1119415/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2012/01/28/england/league-two/barnet-fc/crewe-alexandra-fc/1119413/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2012/01/28/england/league-two/bristol-rovers-fc/bradford-city-afc/1119412/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2012/01/28/england/league-two/torquay-united-fc/northampton-town-fc/1119411/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2012/01/28/england/league-two/dagenham--redbridge-fc/rotherham-united-fc/1119410/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2012/01/28/england/league-two/afc-wimbledon/aldershot-town-fc/1119409/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2012/01/28/england/league-two/accrington-stanley-fc/gillingham-fc/1119408/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2012/01/29/england/league-two/burton-albion-fc/oxford-united-fc/1119406/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2012/01/31/england/league-two/southend-united-fc/swindon-town-fc/1119414/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2012/02/04/england/league-two/plymouth-argyle-fc/southend-united-fc/1119425/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2012/02/07/england/league-two/crawley-town-football-club/cheltenham-town-fc/1119374/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2012/02/10/england/league-two/southend-united-fc/rotherham-united-fc/1119440/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2012/02/11/england/league-two/bristol-rovers-fc/morecambe-fc/1119437/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2012/02/11/england/league-two/hereford-united-fc/cheltenham-town-fc/1119433/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2012/02/11/england/league-two/torquay-united-fc/shrewsbury-town-fc/1119432/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2012/02/13/england/league-two/gillingham-fc/southend-united-fc/1119447/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2012/02/14/england/league-two/shrewsbury-town-fc/bristol-rovers-fc/1119452/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2012/02/14/england/league-two/morecambe-fc/macclesfield-town-fc/1119451/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2012/02/14/england/league-two/northampton-town-fc/afc-wimbledon/1119450/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2012/02/14/england/league-two/bradford-city-afc/port-vale-fc/1119449/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2012/02/14/england/league-two/cheltenham-town-fc/torquay-united-fc/1119448/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2012/01/02/england/league-two/southend-united-fc/dagenham--redbridge-fc/1119361/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2012/01/02/england/league-two/swindon-town-fc/afc-wimbledon/1119360/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2012/01/02/england/league-two/shrewsbury-town-fc/northampton-town-fc/1119359/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2012/01/02/england/league-two/burton-albion-fc/hereford-united-fc/1119358/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2012/01/02/england/league-two/plymouth-argyle-fc/torquay-united-fc/1119357/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2012/01/06/england/league-two/burton-albion-fc/accrington-stanley-fc/1119370/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2012/01/07/england/league-two/aldershot-town-fc/oxford-united-fc/1119379/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2012/01/07/england/league-two/southend-united-fc/port-vale-fc/1119377/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2012/01/07/england/league-two/morecambe-fc/northampton-town-fc/1119375/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2012/01/07/england/league-two/crewe-alexandra-fc/plymouth-argyle-fc/1119372/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2012/01/10/england/league-two/hereford-united-fc/bristol-rovers-fc/1119369/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2012/01/14/england/league-two/macclesfield-town-fc/torquay-united-fc/1119392/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2012/01/14/england/league-two/rotherham-united-fc/swindon-town-fc/1119391/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2012/01/14/england/league-two/port-vale-fc/afc-wimbledon/1119390/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2012/01/14/england/league-two/oxford-united-fc/crewe-alexandra-fc/1119389/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2012/01/14/england/league-two/northampton-town-fc/southend-united-fc/1119388/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2012/01/14/england/league-two/bristol-rovers-fc/crawley-town-football-club/1119387/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2012/01/14/england/league-two/dagenham--redbridge-fc/hereford-united-fc/1119386/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2012/01/14/england/league-two/cheltenham-town-fc/aldershot-town-fc/1119385/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2012/01/14/england/league-two/bradford-city-afc/morecambe-fc/1119384/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2012/01/14/england/league-two/plymouth-argyle-fc/burton-albion-fc/1119383/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2012/01/14/england/league-two/accrington-stanley-fc/barnet-fc/1119382/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2012/01/14/england/league-two/shrewsbury-town-fc/gillingham-fc/1119381/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2012/01/21/england/league-two/northampton-town-fc/barnet-fc/1119404/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2012/01/21/england/league-two/aldershot-town-fc/accrington-stanley-fc/1119403/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2012/01/21/england/league-two/gillingham-fc/afc-wimbledon/1119402/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2012/01/21/england/league-two/morecambe-fc/torquay-united-fc/1119401/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2012/01/21/england/league-two/swindon-town-fc/macclesfield-town-fc/1119400/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2012/01/21/england/league-two/oxford-united-fc/hereford-united-fc/1119399/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2012/01/21/england/league-two/crewe-alexandra-fc/dagenham--redbridge-fc/1119398/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2011/12/26/england/league-two/bristol-rovers-fc/plymouth-argyle-fc/1119338/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2011/12/26/england/league-two/afc-wimbledon/oxford-united-fc/1119334/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2011/12/26/england/league-two/dagenham--redbridge-fc/barnet-fc/1119342/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2011/12/26/england/league-two/hereford-united-fc/port-vale-fc/1119339/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2011/12/26/england/league-two/cheltenham-town-fc/shrewsbury-town-fc/1119344/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2011/12/26/england/league-two/torquay-united-fc/swindon-town-fc/1119343/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2011/12/26/england/league-two/macclesfield-town-fc/rotherham-united-fc/1119341/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2011/12/26/england/league-two/morecambe-fc/accrington-stanley-fc/1119340/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2011/12/26/england/league-two/northampton-town-fc/burton-albion-fc/1119337/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2011/12/26/england/league-two/crawley-town-football-club/gillingham-fc/1119336/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2011/12/26/england/league-two/bradford-city-afc/crewe-alexandra-fc/1119335/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2011/12/30/england/league-two/crawley-town-football-club/barnet-fc/1119352/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2011/12/30/england/league-two/cheltenham-town-fc/rotherham-united-fc/1119349/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2011/12/30/england/league-two/dagenham--redbridge-fc/gillingham-fc/1119346/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2011/12/30/england/league-two/hereford-united-fc/accrington-stanley-fc/1119356/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2011/12/31/england/league-two/morecambe-fc/burton-albion-fc/1119355/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2011/12/31/england/league-two/aldershot-town-fc/plymouth-argyle-fc/1119351/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2011/12/31/england/league-two/torquay-united-fc/oxford-united-fc/1119347/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2011/12/31/england/league-two/macclesfield-town-fc/port-vale-fc/1119348/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2011/12/31/england/league-two/afc-wimbledon/southend-united-fc/1119354/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2011/12/31/england/league-two/bradford-city-afc/shrewsbury-town-fc/1119353/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2011/12/31/england/league-two/northampton-town-fc/swindon-town-fc/1119350/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2011/12/31/england/league-two/bristol-rovers-fc/crewe-alexandra-fc/1119345/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2012/01/02/england/league-two/port-vale-fc/cheltenham-town-fc/1119368/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2012/01/02/england/league-two/oxford-united-fc/crawley-town-football-club/1119367/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2012/01/02/england/league-two/barnet-fc/bristol-rovers-fc/1119366/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2012/01/02/england/league-two/gillingham-fc/aldershot-town-fc/1119365/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2012/01/02/england/league-two/accrington-stanley-fc/macclesfield-town-fc/1119364/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2012/01/02/england/league-two/rotherham-united-fc/bradford-city-afc/1119363/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2012/01/02/england/league-two/crewe-alexandra-fc/morecambe-fc/1119362/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2011/11/26/england/league-two/shrewsbury-town-fc/morecambe-fc/1119303/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2011/11/26/england/league-two/oxford-united-fc/cheltenham-town-fc/1119302/?ICID=PL_MS_02
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-11-8c6e4dc00517> in <module>()
#      46             #todo map names team_mapping = map_names(stuffstuff)
#      47             homeID, awayID = [tm[x] for x in [' '.join(url_[9].split('-')),' '.join(url_[10].split('-'))]]
# ---> 48             driver2.get(url)
#      49             time.sleep(0.6)
#      50             names = [[],[]]
#
# /home/mace/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     266         Loads a web page in the current browser session.
#     267         """
# --> 268         self.execute(Command.GET, {'url': url})
#     269
#     270     @property
#
# /home/mace/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     254         response = self.command_executor.execute(driver_command, params)
#     255         if response:
# --> 256             self.error_handler.check_response(response)
#     257             response['value'] = self._unwrap_value(
#     258                 response.get('value', None))
#
# /home/mace/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     192         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     193             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 194         raise exception_class(message, screen, stacktrace)
#     195
#     196     def _value_or_default(self, obj, key, default):
#
# TimeoutException: Message: timeout
#   (Session info: chrome=62.0.3202.62)
#   (Driver info: chromedriver=2.31.488763 (092de99f48a300323ecf8c2a4e2e7cab51de5ba8),platform=Linux 4.9.0-4-amd64 x86_64)

# %%
c.execute('select * from match')
match_cols =[desc[0] for desc in c.description]

# url_base = 'http://de.soccerway.com/national/england/league-one/20162017/regular-season/r36641/matches/?ICID=PL_3N_02'
url_base = 'http://de.soccerway.com/national/england/league-two/20162017/regular-season/r36644/matches/?ICID=PL_3N_02

# url_base = 'http://de.soccerway.com/national/netherlands/eredivisie/20162017/regular-season/r36385/matches/?ICID=PL_3N_02'

ligaID = 61
odds_data = pd.concat((pd.read_csv(f, dtype={'Date':str, 'AwayTeam':str, 'HomeTeam':str}) for f in csv_files_dict[ligaID]))
odds_data['Date'] = odds_data['Date'].apply(date_conv)
odds_data.rename(columns={'AS':'AShot', 'HS':'HShot', 'BbAv>2.5':'BbAvo25', 'BbAv<2.5':'BbAvu25', 'BbMx>2.5':'BbMxo25', 'BbMx<2.5':'BbMxu25' }, inplace=True)
tm2 = {v[1]:k for k,v in utils.match_club_names([x for x in c.execute('SELECT DISTINCT name, sofifaTeamID FROM team WHERE ligaID=? GROUP BY name', (ligaID,))],list( odds_data['AwayTeam'].dropna().unique())).items()}
driver.get(url_base)
# this can be activated to skip pages in the beginnning
# for _ in range(2):
#     driver.find_element_by_css_selector('.previous').click()
#     time.sleep(0.5)
for select in range(2,10):
    soccerway_teams = []
    while True:
        time.sleep(2.3)
        matches = driver.find_elements_by_css_selector('.score-time.score')
        for match in matches:
            url = match.find_element_by_tag_name('a').get_attribute('href')
            url_ = url.split('/')
            match_dict = dict.fromkeys(match_cols, -1)

            print(url)
            date = datetime(*[int(x) for x in url_[4:7]])
            patch = find_patch_id(date)

            
            
#             TODO select team name by title if errors occur due to incomplete team names
            for teamb in driver.find_elements_by_xpath('//td[@class="team team-b "]/a'):
                soccerway_teams.append(teamb.get_attribute('href').split('/')[5].replace('-', ' '))
            for teamb in driver.find_elements_by_xpath('//td[@class="team team-a "]/a'):
                soccerway_teams.append(teamb.get_attribute('href').split('/')[5].replace('-', ' '))
               
            soccerway_teams = list(set(filter(None,soccerway_teams)))
            if len(soccerway_teams) > 15:
                tm_raw = utils.match_club_names([name for name in c.execute('SELECT name, teamID FROM team WHERE patchID IS '+str(find_patch_id(date))+' AND ligaID IS '+str(ligaID))], soccerway_teams)
                tm = {key:val[1] for key,val in zip(tm_raw.keys(), tm_raw.values())}
            matchID = url_[11]
            #todo map names team_mapping = map_names(stuffstuff)
            homeID, awayID = [tm[x] for x in [' '.join(url_[9].split('-')),' '.join(url_[10].split('-'))]]
            driver2.get(url)
            time.sleep(0.6)
            names = [[],[]]
            
            for p in driver2.find_elements_by_xpath('//div[@class="container left"]//tr'):
                try:
                    jersey = p.find_element_by_class_name('shirtnumber').text
                    name = ' '.join(p.find_element_by_tag_name('a').get_attribute('href').split('/')[4].split('-'))
                    names[0].append((name, jersey))
                except NoSuchElementException:
                    pass
                
            for p in driver2.find_elements_by_xpath('//div[@class="container right"]//tr'):
                try:
                    jersey = p.find_element_by_class_name('shirtnumber').text
                    name = ' '.join(p.find_element_by_tag_name('a').get_attribute('href').split('/')[4].split('-'))
                    names[1].append((name, jersey))
                except NoSuchElementException:
                    pass

            pid = utils.match_player([[x for x in c.execute('SELECT name, playerID, jersey from player WHERE teamID IS ?', (homeID, ))],[x for x in c.execute('SELECT name, playerID, jersey from player WHERE teamID IS ?', (awayID, ))]], names)
            match_dict['patch'] = patch
            match_dict['matchID'] = matchID
            match_dict['date'] = date
            match_dict['ligaID'] = ligaID
            match_dict['homeID'] = homeID
            match_dict['awayID'] = awayID
            match_dict['url'] = url
            #die Daten aus pandas auslesen und ins data_dict uebertragen
            
            game = odds_data[(odds_data['Date']==date) & (odds_data['HomeTeam']== tm2[int(homeID/1000000)]) & (odds_data['AwayTeam']==tm2[int(awayID/1000000)]) ]
            if game.shape[0] == 0:
                continue
            for col in match_cols[42:]:
                if col in game.columns:
                    match_dict[col] = game[col].iloc([0])[0]
            for i, p in enumerate(match_cols[6:42]):
                match_dict[p] = pid[i]

            match_values =  [match_dict[x] for x in match_cols]
            try:
                c.execute('INSERT OR IGNORE INTO match VALUES('+','.join(["?" for x in match_cols ])+')', (*match_values,))
                con.commit()
            except sqlite3.OperationalError:
                print('INSERT OR IGNORE INTO match VALUES('+','.join(["?" for x in match_cols ])+')', (*[match_dict[x] for x in match_cols]))
        print('=============Page Done============')
        try:
            driver.find_element_by_css_selector('.previous.disabled')
            break
        except NoSuchElementException:
            driver.find_element_by_css_selector('.previous').click()

    s = Select(driver.find_element_by_id('season_id_selector'))
    s.select_by_index(select)
    driver.find_elements_by_xpath('//*[@id="submenu"]//li')[1].click()
# Out:
#   File "<ipython-input-11-2c2103d3a1d8>", line 5
#     url_base = 'http://de.soccerway.com/national/england/league-two/20162017/regular-season/r36644/matches/?ICID=PL_3N_02
#                                                                                                                          ^
# SyntaxError: EOL while scanning string literal

# %%
c.execute('select * from match')
match_cols =[desc[0] for desc in c.description]

# url_base = 'http://de.soccerway.com/national/england/league-one/20162017/regular-season/r36641/matches/?ICID=PL_3N_02'
#url_base = 'http://de.soccerway.com/national/england/league-two/20162017/regular-season/r36644/matches/?ICID=PL_3N_02

url_base = 'http://de.soccerway.com/national/netherlands/eredivisie/20162017/regular-season/r36385/matches/?ICID=PL_3N_02'

ligaID = 10
odds_data = pd.concat((pd.read_csv(f, dtype={'Date':str, 'AwayTeam':str, 'HomeTeam':str}) for f in csv_files_dict[ligaID]))
odds_data['Date'] = odds_data['Date'].apply(date_conv)
odds_data.rename(columns={'AS':'AShot', 'HS':'HShot', 'BbAv>2.5':'BbAvo25', 'BbAv<2.5':'BbAvu25', 'BbMx>2.5':'BbMxo25', 'BbMx<2.5':'BbMxu25' }, inplace=True)
tm2 = {v[1]:k for k,v in utils.match_club_names([x for x in c.execute('SELECT DISTINCT name, sofifaTeamID FROM team WHERE ligaID=? GROUP BY name', (ligaID,))],list( odds_data['AwayTeam'].dropna().unique())).items()}
driver.get(url_base)
# this can be activated to skip pages in the beginnning
# for _ in range(2):
#     driver.find_element_by_css_selector('.previous').click()
#     time.sleep(0.5)
for select in range(2,10):
    soccerway_teams = []
    while True:
        time.sleep(2.3)
        matches = driver.find_elements_by_css_selector('.score-time.score')
        for match in matches:
            url = match.find_element_by_tag_name('a').get_attribute('href')
            url_ = url.split('/')
            match_dict = dict.fromkeys(match_cols, -1)

            print(url)
            date = datetime(*[int(x) for x in url_[4:7]])
            patch = find_patch_id(date)

            
            
#             TODO select team name by title if errors occur due to incomplete team names
            for teamb in driver.find_elements_by_xpath('//td[@class="team team-b "]/a'):
                soccerway_teams.append(teamb.get_attribute('href').split('/')[5].replace('-', ' '))
            for teamb in driver.find_elements_by_xpath('//td[@class="team team-a "]/a'):
                soccerway_teams.append(teamb.get_attribute('href').split('/')[5].replace('-', ' '))
               
            soccerway_teams = list(set(filter(None,soccerway_teams)))
            if len(soccerway_teams) > 15:
                tm_raw = utils.match_club_names([name for name in c.execute('SELECT name, teamID FROM team WHERE patchID IS '+str(find_patch_id(date))+' AND ligaID IS '+str(ligaID))], soccerway_teams)
                tm = {key:val[1] for key,val in zip(tm_raw.keys(), tm_raw.values())}
            matchID = url_[11]
            #todo map names team_mapping = map_names(stuffstuff)
            homeID, awayID = [tm[x] for x in [' '.join(url_[9].split('-')),' '.join(url_[10].split('-'))]]
            driver2.get(url)
            time.sleep(0.6)
            names = [[],[]]
            
            for p in driver2.find_elements_by_xpath('//div[@class="container left"]//tr'):
                try:
                    jersey = p.find_element_by_class_name('shirtnumber').text
                    name = ' '.join(p.find_element_by_tag_name('a').get_attribute('href').split('/')[4].split('-'))
                    names[0].append((name, jersey))
                except NoSuchElementException:
                    pass
                
            for p in driver2.find_elements_by_xpath('//div[@class="container right"]//tr'):
                try:
                    jersey = p.find_element_by_class_name('shirtnumber').text
                    name = ' '.join(p.find_element_by_tag_name('a').get_attribute('href').split('/')[4].split('-'))
                    names[1].append((name, jersey))
                except NoSuchElementException:
                    pass

            pid = utils.match_player([[x for x in c.execute('SELECT name, playerID, jersey from player WHERE teamID IS ?', (homeID, ))],[x for x in c.execute('SELECT name, playerID, jersey from player WHERE teamID IS ?', (awayID, ))]], names)
            match_dict['patch'] = patch
            match_dict['matchID'] = matchID
            match_dict['date'] = date
            match_dict['ligaID'] = ligaID
            match_dict['homeID'] = homeID
            match_dict['awayID'] = awayID
            match_dict['url'] = url
            #die Daten aus pandas auslesen und ins data_dict uebertragen
            
            game = odds_data[(odds_data['Date']==date) & (odds_data['HomeTeam']== tm2[int(homeID/1000000)]) & (odds_data['AwayTeam']==tm2[int(awayID/1000000)]) ]
            if game.shape[0] == 0:
                continue
            for col in match_cols[42:]:
                if col in game.columns:
                    match_dict[col] = game[col].iloc([0])[0]
            for i, p in enumerate(match_cols[6:42]):
                match_dict[p] = pid[i]

            match_values =  [match_dict[x] for x in match_cols]
            try:
                c.execute('INSERT OR IGNORE INTO match VALUES('+','.join(["?" for x in match_cols ])+')', (*match_values,))
                con.commit()
            except sqlite3.OperationalError:
                print('INSERT OR IGNORE INTO match VALUES('+','.join(["?" for x in match_cols ])+')', (*[match_dict[x] for x in match_cols]))
        print('=============Page Done============')
        try:
            driver.find_element_by_css_selector('.previous.disabled')
            break
        except NoSuchElementException:
            driver.find_element_by_css_selector('.previous').click()

    s = Select(driver.find_element_by_id('season_id_selector'))
    s.select_by_index(select)
    driver.find_elements_by_xpath('//*[@id="submenu"]//li')[1].click()
# Out:
# http://de.soccerway.com/matches/2017/04/16/netherlands/eredivisie/stichting-fc-groningen/bvo-fc-zwolle/2240540/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2017/04/16/netherlands/eredivisie/feyenoord-rotterdam-nv/stichting-fc-utrecht/2240539/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2017/04/16/netherlands/eredivisie/afc-ajax/sportclub-heerenveen/2240541/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2017/04/21/netherlands/eredivisie/sportclub-heerenveen/sbv-willem-ii-tilburg/2240542/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2017/04/22/netherlands/eredivisie/nijmegen-eendracht-combinatie/sbv-excelsior/2240543/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2017/04/22/netherlands/eredivisie/stichting-az/stichting-fc-twente-65/2240946/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2017/04/22/netherlands/eredivisie/bvo-fc-zwolle/stichting-heracles-almelo/2240544/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2017/04/22/netherlands/eredivisie/stichting-go-ahead-eagles/stichting-fc-groningen/2240545/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2017/04/23/netherlands/eredivisie/stichting-fc-utrecht/roda-jc/2240546/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2017/04/23/netherlands/eredivisie/sbv-vitesse/feyenoord-rotterdam-nv/2240548/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2017/04/23/netherlands/eredivisie/sparta-rotterdam-bv/hfc-ado-den-haag/2240547/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2017/04/23/netherlands/eredivisie/psv-nv/afc-ajax/2240549/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2017/05/07/netherlands/eredivisie/roda-jc/sbv-willem-ii-tilburg/2240553/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2017/05/07/netherlands/eredivisie/bvo-fc-zwolle/sportclub-heerenveen/2240557/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2017/05/07/netherlands/eredivisie/stichting-fc-groningen/psv-nv/2240552/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2017/05/07/netherlands/eredivisie/nijmegen-eendracht-combinatie/stichting-az/2240556/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2017/05/07/netherlands/eredivisie/afc-ajax/stichting-go-ahead-eagles/2240550/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2017/05/07/netherlands/eredivisie/sparta-rotterdam-bv/stichting-fc-twente-65/2240947/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2017/05/07/netherlands/eredivisie/sbv-excelsior/feyenoord-rotterdam-nv/2240551/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2017/05/07/netherlands/eredivisie/stichting-heracles-almelo/hfc-ado-den-haag/2240555/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2017/05/07/netherlands/eredivisie/stichting-fc-utrecht/sbv-vitesse/2240554/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2017/05/14/netherlands/eredivisie/hfc-ado-den-haag/sbv-excelsior/2240558/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2017/05/14/netherlands/eredivisie/psv-nv/bvo-fc-zwolle/2240564/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2017/05/14/netherlands/eredivisie/stichting-az/stichting-fc-utrecht/2240559/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2017/05/14/netherlands/eredivisie/sbv-willem-ii-tilburg/afc-ajax/2240563/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2017/05/14/netherlands/eredivisie/feyenoord-rotterdam-nv/stichting-heracles-almelo/2240560/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2017/05/14/netherlands/eredivisie/stichting-fc-twente-65/stichting-fc-groningen/2240924/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2017/05/14/netherlands/eredivisie/sbv-vitesse/roda-jc/2240565/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2017/05/14/netherlands/eredivisie/stichting-go-ahead-eagles/sparta-rotterdam-bv/2240561/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2017/05/14/netherlands/eredivisie/sportclub-heerenveen/nijmegen-eendracht-combinatie/2240562/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2017/04/01/netherlands/eredivisie/stichting-fc-utrecht/sbv-willem-ii-tilburg/2240514/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2017/04/01/netherlands/eredivisie/stichting-heracles-almelo/sportclub-heerenveen/2240513/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2017/04/02/netherlands/eredivisie/sbv-vitesse/nijmegen-eendracht-combinatie/2240515/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2017/04/02/netherlands/eredivisie/afc-ajax/feyenoord-rotterdam-nv/2240517/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2017/04/02/netherlands/eredivisie/hfc-ado-den-haag/roda-jc/2240516/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2017/04/02/netherlands/eredivisie/stichting-fc-twente-65/stichting-go-ahead-eagles/2240921/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2017/04/04/netherlands/eredivisie/sbv-excelsior/stichting-fc-utrecht/2240518/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2017/04/04/netherlands/eredivisie/sportclub-heerenveen/sparta-rotterdam-bv/2240519/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2017/04/05/netherlands/eredivisie/stichting-heracles-almelo/sbv-vitesse/2240521/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2017/04/05/netherlands/eredivisie/stichting-fc-groningen/nijmegen-eendracht-combinatie/2240522/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2017/04/05/netherlands/eredivisie/sbv-willem-ii-tilburg/hfc-ado-den-haag/2240524/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2017/04/05/netherlands/eredivisie/feyenoord-rotterdam-nv/stichting-go-ahead-eagles/2240523/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2017/04/05/netherlands/eredivisie/afc-ajax/stichting-az/2240520/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2017/04/06/netherlands/eredivisie/roda-jc/bvo-fc-zwolle/2240525/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2017/04/06/netherlands/eredivisie/stichting-fc-twente-65/psv-nv/2240922/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2017/04/07/netherlands/eredivisie/sparta-rotterdam-bv/sbv-excelsior/2240526/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2017/04/08/netherlands/eredivisie/sbv-vitesse/sportclub-heerenveen/2240527/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2017/04/08/netherlands/eredivisie/nijmegen-eendracht-combinatie/afc-ajax/2240529/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2017/04/08/netherlands/eredivisie/hfc-ado-den-haag/stichting-fc-groningen/2240528/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2017/04/08/netherlands/eredivisie/stichting-go-ahead-eagles/stichting-heracles-almelo/2240530/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2017/04/09/netherlands/eredivisie/stichting-az/roda-jc/2240531/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2017/04/09/netherlands/eredivisie/stichting-fc-utrecht/stichting-fc-twente-65/2240945/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2017/04/09/netherlands/eredivisie/bvo-fc-zwolle/feyenoord-rotterdam-nv/2240532/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2017/04/09/netherlands/eredivisie/psv-nv/sbv-willem-ii-tilburg/2240533/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2017/04/14/netherlands/eredivisie/stichting-heracles-almelo/stichting-az/2240534/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2017/04/15/netherlands/eredivisie/roda-jc/sparta-rotterdam-bv/2240535/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2017/04/15/netherlands/eredivisie/sbv-excelsior/sbv-vitesse/2240537/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2017/04/15/netherlands/eredivisie/hfc-ado-den-haag/psv-nv/2240536/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2017/04/15/netherlands/eredivisie/stichting-fc-twente-65/nijmegen-eendracht-combinatie/2240923/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2017/04/16/netherlands/eredivisie/sbv-willem-ii-tilburg/stichting-go-ahead-eagles/2240538/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2017/03/03/netherlands/eredivisie/sportclub-heerenveen/stichting-go-ahead-eagles/2240488/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2017/03/04/netherlands/eredivisie/stichting-fc-twente-65/sbv-willem-ii-tilburg/2240920/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2017/03/04/netherlands/eredivisie/psv-nv/roda-jc/2240487/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2017/03/04/netherlands/eredivisie/bvo-fc-zwolle/sbv-vitesse/2240489/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2017/03/05/netherlands/eredivisie/sparta-rotterdam-bv/feyenoord-rotterdam-nv/2240490/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2017/03/05/netherlands/eredivisie/stichting-az/sbv-excelsior/2240486/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2017/03/05/netherlands/eredivisie/stichting-fc-utrecht/hfc-ado-den-haag/2240492/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2017/03/05/netherlands/eredivisie/stichting-fc-groningen/afc-ajax/2240491/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2017/03/05/netherlands/eredivisie/nijmegen-eendracht-combinatie/stichting-heracles-almelo/2240493/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2017/03/10/netherlands/eredivisie/sbv-vitesse/sparta-rotterdam-bv/2240494/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2017/03/11/netherlands/eredivisie/hfc-ado-den-haag/nijmegen-eendracht-combinatie/2240495/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2017/03/11/netherlands/eredivisie/stichting-heracles-almelo/stichting-fc-utrecht/2240497/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2017/03/11/netherlands/eredivisie/stichting-go-ahead-eagles/psv-nv/2240496/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2017/03/11/netherlands/eredivisie/sbv-excelsior/sportclub-heerenveen/2240498/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2017/03/12/netherlands/eredivisie/sbv-willem-ii-tilburg/bvo-fc-zwolle/2240499/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2017/03/12/netherlands/eredivisie/roda-jc/stichting-fc-groningen/2240501/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2017/03/12/netherlands/eredivisie/feyenoord-rotterdam-nv/stichting-az/2240500/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2017/03/12/netherlands/eredivisie/afc-ajax/stichting-fc-twente-65/2240943/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2017/03/17/netherlands/eredivisie/roda-jc/stichting-fc-twente-65/2240944/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2017/03/18/netherlands/eredivisie/stichting-fc-groningen/sbv-willem-ii-tilburg/2240502/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2017/03/18/netherlands/eredivisie/psv-nv/sbv-vitesse/2240504/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2017/03/18/netherlands/eredivisie/nijmegen-eendracht-combinatie/stichting-fc-utrecht/2240503/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2017/03/18/netherlands/eredivisie/sparta-rotterdam-bv/stichting-heracles-almelo/2240509/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2017/03/19/netherlands/eredivisie/sportclub-heerenveen/feyenoord-rotterdam-nv/2240506/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2017/03/19/netherlands/eredivisie/sbv-excelsior/afc-ajax/2240508/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2017/03/19/netherlands/eredivisie/stichting-go-ahead-eagles/bvo-fc-zwolle/2240507/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2017/03/19/netherlands/eredivisie/stichting-az/hfc-ado-den-haag/2240505/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2017/04/01/netherlands/eredivisie/bvo-fc-zwolle/sbv-excelsior/2240511/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2017/04/01/netherlands/eredivisie/stichting-az/stichting-fc-groningen/2240510/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2017/04/01/netherlands/eredivisie/sparta-rotterdam-bv/psv-nv/2240512/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2017/02/05/netherlands/eredivisie/stichting-fc-twente-65/feyenoord-rotterdam-nv/2240918/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2017/02/05/netherlands/eredivisie/sparta-rotterdam-bv/bvo-fc-zwolle/2240460/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2017/02/05/netherlands/eredivisie/stichting-fc-utrecht/sportclub-heerenveen/2240461/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2017/02/10/netherlands/eredivisie/bvo-fc-zwolle/nijmegen-eendracht-combinatie/2240462/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2017/02/11/netherlands/eredivisie/stichting-heracles-almelo/roda-jc/2240463/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2017/02/11/netherlands/eredivisie/feyenoord-rotterdam-nv/stichting-fc-groningen/2240465/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2017/02/11/netherlands/eredivisie/stichting-go-ahead-eagles/hfc-ado-den-haag/2240464/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2017/02/11/netherlands/eredivisie/sbv-vitesse/sbv-willem-ii-tilburg/2240466/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2017/02/12/netherlands/eredivisie/sbv-excelsior/stichting-fc-twente-65/2240941/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2017/02/12/netherlands/eredivisie/sportclub-heerenveen/stichting-az/2240468/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2017/02/12/netherlands/eredivisie/afc-ajax/sparta-rotterdam-bv/2240467/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2017/02/12/netherlands/eredivisie/psv-nv/stichting-fc-utrecht/2240469/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2017/02/17/netherlands/eredivisie/roda-jc/stichting-go-ahead-eagles/2240470/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2017/02/18/netherlands/eredivisie/stichting-fc-twente-65/sportclub-heerenveen/2240919/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2017/02/18/netherlands/eredivisie/stichting-heracles-almelo/sbv-excelsior/2240474/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2017/02/18/netherlands/eredivisie/psv-nv/nijmegen-eendracht-combinatie/2240472/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2017/02/18/netherlands/eredivisie/stichting-fc-utrecht/bvo-fc-zwolle/2240473/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2017/02/19/netherlands/eredivisie/sbv-willem-ii-tilburg/stichting-az/2240471/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2017/02/19/netherlands/eredivisie/sparta-rotterdam-bv/stichting-fc-groningen/2240476/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2017/02/19/netherlands/eredivisie/sbv-vitesse/afc-ajax/2240475/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2017/02/19/netherlands/eredivisie/hfc-ado-den-haag/feyenoord-rotterdam-nv/2240477/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2017/02/24/netherlands/eredivisie/hfc-ado-den-haag/stichting-fc-twente-65/2240942/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2017/02/25/netherlands/eredivisie/stichting-fc-groningen/stichting-fc-utrecht/2240478/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2017/02/25/netherlands/eredivisie/nijmegen-eendracht-combinatie/sparta-rotterdam-bv/2240484/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2017/02/25/netherlands/eredivisie/sbv-excelsior/sbv-willem-ii-tilburg/2240480/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2017/02/25/netherlands/eredivisie/sportclub-heerenveen/roda-jc/2240481/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2017/02/26/netherlands/eredivisie/stichting-go-ahead-eagles/sbv-vitesse/2240482/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2017/02/26/netherlands/eredivisie/feyenoord-rotterdam-nv/psv-nv/2240483/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2017/02/26/netherlands/eredivisie/stichting-az/bvo-fc-zwolle/2240479/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2017/02/26/netherlands/eredivisie/afc-ajax/stichting-heracles-almelo/2240485/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2017/01/14/netherlands/eredivisie/stichting-heracles-almelo/stichting-fc-groningen/2240432/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2017/01/14/netherlands/eredivisie/sparta-rotterdam-bv/stichting-fc-utrecht/2240434/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2017/01/15/netherlands/eredivisie/roda-jc/feyenoord-rotterdam-nv/2240435/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2017/01/15/netherlands/eredivisie/sbv-vitesse/stichting-fc-twente-65/2240938/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2017/01/15/netherlands/eredivisie/bvo-fc-zwolle/afc-ajax/2240436/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2017/01/15/netherlands/eredivisie/sbv-willem-ii-tilburg/nijmegen-eendracht-combinatie/2240437/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2017/01/20/netherlands/eredivisie/stichting-fc-twente-65/stichting-heracles-almelo/2240917/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2017/01/21/netherlands/eredivisie/stichting-az/sparta-rotterdam-bv/2240438/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2017/01/21/netherlands/eredivisie/feyenoord-rotterdam-nv/sbv-willem-ii-tilburg/2240440/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2017/01/21/netherlands/eredivisie/hfc-ado-den-haag/bvo-fc-zwolle/2240439/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2017/01/21/netherlands/eredivisie/stichting-fc-groningen/sbv-vitesse/2240441/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2017/01/22/netherlands/eredivisie/stichting-fc-utrecht/afc-ajax/2240442/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2017/01/22/netherlands/eredivisie/nijmegen-eendracht-combinatie/roda-jc/2240444/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2017/01/22/netherlands/eredivisie/sbv-excelsior/stichting-go-ahead-eagles/2240443/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2017/01/22/netherlands/eredivisie/psv-nv/sportclub-heerenveen/2240445/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2017/01/27/netherlands/eredivisie/sbv-willem-ii-tilburg/sparta-rotterdam-bv/2240446/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2017/01/28/netherlands/eredivisie/stichting-go-ahead-eagles/stichting-fc-utrecht/2240447/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2017/01/28/netherlands/eredivisie/roda-jc/sbv-excelsior/2240449/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2017/01/28/netherlands/eredivisie/stichting-heracles-almelo/psv-nv/2240448/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2017/01/29/netherlands/eredivisie/sportclub-heerenveen/stichting-fc-groningen/2240451/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2017/01/29/netherlands/eredivisie/bvo-fc-zwolle/stichting-fc-twente-65/2240940/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2017/01/29/netherlands/eredivisie/afc-ajax/hfc-ado-den-haag/2240452/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2017/01/29/netherlands/eredivisie/sbv-vitesse/stichting-az/2240450/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2017/01/29/netherlands/eredivisie/feyenoord-rotterdam-nv/nijmegen-eendracht-combinatie/2240453/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2017/02/03/netherlands/eredivisie/hfc-ado-den-haag/sbv-vitesse/2240454/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2017/02/04/netherlands/eredivisie/nijmegen-eendracht-combinatie/stichting-go-ahead-eagles/2240455/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2017/02/04/netherlands/eredivisie/sbv-willem-ii-tilburg/stichting-heracles-almelo/2240457/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2017/02/04/netherlands/eredivisie/stichting-az/psv-nv/2240456/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2017/02/04/netherlands/eredivisie/stichting-fc-groningen/sbv-excelsior/2240458/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2017/02/05/netherlands/eredivisie/roda-jc/afc-ajax/2240459/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2016/12/02/netherlands/eredivisie/stichting-heracles-almelo/nijmegen-eendracht-combinatie/2240406/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2016/12/03/netherlands/eredivisie/stichting-go-ahead-eagles/sportclub-heerenveen/2240407/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2016/12/03/netherlands/eredivisie/roda-jc/psv-nv/2240409/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2016/12/03/netherlands/eredivisie/sbv-excelsior/stichting-az/2240408/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2016/12/03/netherlands/eredivisie/sbv-vitesse/bvo-fc-zwolle/2240413/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2016/12/04/netherlands/eredivisie/hfc-ado-den-haag/stichting-fc-utrecht/2240411/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2016/12/04/netherlands/eredivisie/sbv-willem-ii-tilburg/stichting-fc-twente-65/2240936/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2016/12/04/netherlands/eredivisie/feyenoord-rotterdam-nv/sparta-rotterdam-bv/2240412/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2016/12/04/netherlands/eredivisie/afc-ajax/stichting-fc-groningen/2240410/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2016/12/09/netherlands/eredivisie/stichting-fc-groningen/roda-jc/2240414/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2016/12/10/netherlands/eredivisie/nijmegen-eendracht-combinatie/hfc-ado-den-haag/2240415/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2016/12/10/netherlands/eredivisie/sportclub-heerenveen/sbv-excelsior/2240417/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2016/12/10/netherlands/eredivisie/psv-nv/stichting-go-ahead-eagles/2240416/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2016/12/10/netherlands/eredivisie/bvo-fc-zwolle/sbv-willem-ii-tilburg/2240418/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2016/12/11/netherlands/eredivisie/sparta-rotterdam-bv/sbv-vitesse/2240419/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2016/12/11/netherlands/eredivisie/stichting-fc-utrecht/stichting-heracles-almelo/2240421/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2016/12/11/netherlands/eredivisie/stichting-az/feyenoord-rotterdam-nv/2240420/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2016/12/11/netherlands/eredivisie/stichting-fc-twente-65/afc-ajax/2240915/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2016/12/16/netherlands/eredivisie/sbv-willem-ii-tilburg/sportclub-heerenveen/2240422/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2016/12/17/netherlands/eredivisie/roda-jc/stichting-fc-utrecht/2240423/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2016/12/17/netherlands/eredivisie/feyenoord-rotterdam-nv/sbv-vitesse/2240424/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2016/12/17/netherlands/eredivisie/stichting-fc-twente-65/stichting-az/2240916/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2016/12/18/netherlands/eredivisie/sbv-excelsior/nijmegen-eendracht-combinatie/2240427/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2016/12/18/netherlands/eredivisie/stichting-fc-groningen/stichting-go-ahead-eagles/2240428/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2016/12/18/netherlands/eredivisie/stichting-heracles-almelo/bvo-fc-zwolle/2240426/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2016/12/18/netherlands/eredivisie/hfc-ado-den-haag/sparta-rotterdam-bv/2240425/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2016/12/18/netherlands/eredivisie/afc-ajax/psv-nv/2240429/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2017/01/13/netherlands/eredivisie/stichting-go-ahead-eagles/stichting-az/2240430/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2017/01/14/netherlands/eredivisie/sportclub-heerenveen/hfc-ado-den-haag/2240431/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2017/01/14/netherlands/eredivisie/psv-nv/sbv-excelsior/2240433/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2016/10/30/netherlands/eredivisie/stichting-fc-utrecht/nijmegen-eendracht-combinatie/2240380/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2016/10/30/netherlands/eredivisie/feyenoord-rotterdam-nv/sportclub-heerenveen/2240379/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2016/10/30/netherlands/eredivisie/hfc-ado-den-haag/stichting-az/2240381/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2016/11/04/netherlands/eredivisie/sparta-rotterdam-bv/sportclub-heerenveen/2240382/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2016/11/05/netherlands/eredivisie/hfc-ado-den-haag/sbv-willem-ii-tilburg/2240385/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2016/11/05/netherlands/eredivisie/psv-nv/stichting-fc-twente-65/2240930/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2016/11/05/netherlands/eredivisie/nijmegen-eendracht-combinatie/stichting-fc-groningen/2240384/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2016/11/05/netherlands/eredivisie/bvo-fc-zwolle/roda-jc/2240383/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2016/11/06/netherlands/eredivisie/stichting-fc-utrecht/sbv-excelsior/2240386/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2016/11/06/netherlands/eredivisie/sbv-vitesse/stichting-heracles-almelo/2240388/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2016/11/06/netherlands/eredivisie/stichting-az/afc-ajax/2240387/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2016/11/06/netherlands/eredivisie/stichting-go-ahead-eagles/feyenoord-rotterdam-nv/2240389/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2016/11/19/netherlands/eredivisie/stichting-heracles-almelo/stichting-go-ahead-eagles/2240391/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2016/11/19/netherlands/eredivisie/sportclub-heerenveen/sbv-vitesse/2240390/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2016/11/19/netherlands/eredivisie/sbv-willem-ii-tilburg/psv-nv/2240392/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2016/11/19/netherlands/eredivisie/stichting-fc-groningen/hfc-ado-den-haag/2240396/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2016/11/19/netherlands/eredivisie/sbv-excelsior/sparta-rotterdam-bv/2240394/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2016/11/20/netherlands/eredivisie/roda-jc/stichting-az/2240395/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2016/11/20/netherlands/eredivisie/stichting-fc-twente-65/stichting-fc-utrecht/2240914/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2016/11/20/netherlands/eredivisie/afc-ajax/nijmegen-eendracht-combinatie/2240393/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2016/11/20/netherlands/eredivisie/feyenoord-rotterdam-nv/bvo-fc-zwolle/2240397/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2016/11/25/netherlands/eredivisie/stichting-go-ahead-eagles/sbv-willem-ii-tilburg/2240398/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2016/11/26/netherlands/eredivisie/sbv-vitesse/sbv-excelsior/2240399/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2016/11/26/netherlands/eredivisie/bvo-fc-zwolle/stichting-fc-groningen/2240401/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2016/11/26/netherlands/eredivisie/psv-nv/hfc-ado-den-haag/2240400/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2016/11/26/netherlands/eredivisie/nijmegen-eendracht-combinatie/stichting-fc-twente-65/2240933/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2016/11/27/netherlands/eredivisie/sparta-rotterdam-bv/roda-jc/2240402/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2016/11/27/netherlands/eredivisie/sportclub-heerenveen/afc-ajax/2240404/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2016/11/27/netherlands/eredivisie/stichting-az/stichting-heracles-almelo/2240403/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2016/11/27/netherlands/eredivisie/stichting-fc-utrecht/feyenoord-rotterdam-nv/2240405/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2016/10/01/netherlands/eredivisie/sportclub-heerenveen/psv-nv/2240352/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2016/10/01/netherlands/eredivisie/stichting-go-ahead-eagles/sbv-excelsior/2240354/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2016/10/02/netherlands/eredivisie/afc-ajax/stichting-fc-utrecht/2240355/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2016/10/02/netherlands/eredivisie/stichting-heracles-almelo/stichting-fc-twente-65/2240928/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2016/10/02/netherlands/eredivisie/sbv-willem-ii-tilburg/feyenoord-rotterdam-nv/2240356/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2016/10/02/netherlands/eredivisie/sparta-rotterdam-bv/stichting-az/2240357/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2016/10/15/netherlands/eredivisie/stichting-fc-utrecht/stichting-go-ahead-eagles/2240359/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2016/10/15/netherlands/eredivisie/sparta-rotterdam-bv/sbv-willem-ii-tilburg/2240358/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2016/10/15/netherlands/eredivisie/psv-nv/stichting-heracles-almelo/2240360/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2016/10/15/netherlands/eredivisie/stichting-fc-groningen/sportclub-heerenveen/2240365/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2016/10/15/netherlands/eredivisie/stichting-az/sbv-vitesse/2240362/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2016/10/16/netherlands/eredivisie/stichting-fc-twente-65/bvo-fc-zwolle/2240912/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2016/10/16/netherlands/eredivisie/nijmegen-eendracht-combinatie/feyenoord-rotterdam-nv/2240364/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2016/10/16/netherlands/eredivisie/sbv-excelsior/roda-jc/2240363/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2016/10/16/netherlands/eredivisie/hfc-ado-den-haag/afc-ajax/2240361/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2016/10/21/netherlands/eredivisie/sbv-excelsior/bvo-fc-zwolle/2240366/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2016/10/22/netherlands/eredivisie/stichting-go-ahead-eagles/stichting-fc-twente-65/2240929/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2016/10/22/netherlands/eredivisie/roda-jc/hfc-ado-den-haag/2240368/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2016/10/22/netherlands/eredivisie/psv-nv/sparta-rotterdam-bv/2240367/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2016/10/22/netherlands/eredivisie/sbv-willem-ii-tilburg/stichting-fc-utrecht/2240369/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2016/10/23/netherlands/eredivisie/nijmegen-eendracht-combinatie/sbv-vitesse/2240370/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2016/10/23/netherlands/eredivisie/stichting-fc-groningen/stichting-az/2240372/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2016/10/23/netherlands/eredivisie/feyenoord-rotterdam-nv/afc-ajax/2240371/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2016/10/23/netherlands/eredivisie/sportclub-heerenveen/stichting-heracles-almelo/2240373/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2016/10/28/netherlands/eredivisie/stichting-fc-twente-65/roda-jc/2240913/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2016/10/29/netherlands/eredivisie/sbv-willem-ii-tilburg/stichting-fc-groningen/2240374/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2016/10/29/netherlands/eredivisie/sbv-vitesse/psv-nv/2240376/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2016/10/29/netherlands/eredivisie/stichting-heracles-almelo/sparta-rotterdam-bv/2240375/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2016/10/29/netherlands/eredivisie/afc-ajax/sbv-excelsior/2240377/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2016/10/30/netherlands/eredivisie/bvo-fc-zwolle/stichting-go-ahead-eagles/2240378/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2016/09/10/netherlands/eredivisie/bvo-fc-zwolle/stichting-fc-utrecht/2240333/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2016/09/10/netherlands/eredivisie/stichting-az/sbv-willem-ii-tilburg/2240326/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2016/09/10/netherlands/eredivisie/nijmegen-eendracht-combinatie/psv-nv/2240327/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2016/09/10/netherlands/eredivisie/sportclub-heerenveen/stichting-fc-twente-65/2240927/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2016/09/10/netherlands/eredivisie/sbv-excelsior/stichting-heracles-almelo/2240329/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2016/09/11/netherlands/eredivisie/feyenoord-rotterdam-nv/hfc-ado-den-haag/2240330/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2016/09/11/netherlands/eredivisie/stichting-go-ahead-eagles/roda-jc/2240332/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2016/09/11/netherlands/eredivisie/stichting-fc-groningen/sparta-rotterdam-bv/2240331/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2016/09/11/netherlands/eredivisie/afc-ajax/sbv-vitesse/2240328/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2016/09/16/netherlands/eredivisie/stichting-fc-utrecht/stichting-fc-groningen/2240334/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2016/09/17/netherlands/eredivisie/stichting-fc-twente-65/hfc-ado-den-haag/2240910/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2016/09/17/netherlands/eredivisie/roda-jc/sportclub-heerenveen/2240336/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2016/09/17/netherlands/eredivisie/sbv-vitesse/stichting-go-ahead-eagles/2240335/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2016/09/17/netherlands/eredivisie/sbv-willem-ii-tilburg/sbv-excelsior/2240337/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2016/09/18/netherlands/eredivisie/sparta-rotterdam-bv/nijmegen-eendracht-combinatie/2240338/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2016/09/18/netherlands/eredivisie/psv-nv/feyenoord-rotterdam-nv/2240340/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2016/09/18/netherlands/eredivisie/bvo-fc-zwolle/stichting-az/2240339/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2016/09/18/netherlands/eredivisie/stichting-heracles-almelo/afc-ajax/2240341/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2016/09/24/netherlands/eredivisie/stichting-fc-groningen/stichting-heracles-almelo/2240343/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2016/09/24/netherlands/eredivisie/hfc-ado-den-haag/sportclub-heerenveen/2240342/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2016/09/24/netherlands/eredivisie/afc-ajax/bvo-fc-zwolle/2240344/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2016/09/24/netherlands/eredivisie/sbv-excelsior/psv-nv/2240346/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2016/09/24/netherlands/eredivisie/stichting-az/stichting-go-ahead-eagles/2240345/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2016/09/25/netherlands/eredivisie/nijmegen-eendracht-combinatie/sbv-willem-ii-tilburg/2240347/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2016/09/25/netherlands/eredivisie/stichting-fc-twente-65/sbv-vitesse/2240911/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2016/09/25/netherlands/eredivisie/stichting-fc-utrecht/sparta-rotterdam-bv/2240348/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2016/09/25/netherlands/eredivisie/feyenoord-rotterdam-nv/roda-jc/2240349/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2016/09/30/netherlands/eredivisie/bvo-fc-zwolle/hfc-ado-den-haag/2240350/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2016/10/01/netherlands/eredivisie/sbv-vitesse/stichting-fc-groningen/2240351/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2016/10/01/netherlands/eredivisie/roda-jc/nijmegen-eendracht-combinatie/2240353/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2016/08/07/netherlands/eredivisie/sparta-rotterdam-bv/afc-ajax/2240300/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2016/08/07/netherlands/eredivisie/stichting-az/sportclub-heerenveen/2240299/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2016/08/07/netherlands/eredivisie/roda-jc/stichting-heracles-almelo/2240301/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2016/08/12/netherlands/eredivisie/sportclub-heerenveen/stichting-fc-utrecht/2240302/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2016/08/13/netherlands/eredivisie/sbv-excelsior/stichting-fc-groningen/2240303/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2016/08/13/netherlands/eredivisie/sbv-vitesse/hfc-ado-den-haag/2240305/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2016/08/13/netherlands/eredivisie/afc-ajax/roda-jc/2240304/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2016/08/13/netherlands/eredivisie/bvo-fc-zwolle/sparta-rotterdam-bv/2240306/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2016/08/14/netherlands/eredivisie/stichting-heracles-almelo/sbv-willem-ii-tilburg/2240307/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2016/08/14/netherlands/eredivisie/feyenoord-rotterdam-nv/stichting-fc-twente-65/2240925/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2016/08/14/netherlands/eredivisie/stichting-go-ahead-eagles/nijmegen-eendracht-combinatie/2240308/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2016/08/14/netherlands/eredivisie/psv-nv/stichting-az/2240309/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2016/08/19/netherlands/eredivisie/sbv-excelsior/hfc-ado-den-haag/2240310/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2016/08/20/netherlands/eredivisie/roda-jc/sbv-vitesse/2240311/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2016/08/20/netherlands/eredivisie/bvo-fc-zwolle/psv-nv/2240313/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2016/08/20/netherlands/eredivisie/afc-ajax/sbv-willem-ii-tilburg/2240312/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2016/08/20/netherlands/eredivisie/nijmegen-eendracht-combinatie/sportclub-heerenveen/2240314/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2016/08/21/netherlands/eredivisie/stichting-fc-groningen/stichting-fc-twente-65/2240926/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2016/08/21/netherlands/eredivisie/sparta-rotterdam-bv/stichting-go-ahead-eagles/2240316/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2016/08/21/netherlands/eredivisie/stichting-fc-utrecht/stichting-az/2240315/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2016/08/21/netherlands/eredivisie/stichting-heracles-almelo/feyenoord-rotterdam-nv/2240317/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2016/08/26/netherlands/eredivisie/sbv-vitesse/stichting-fc-utrecht/2240318/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2016/08/27/netherlands/eredivisie/sbv-willem-ii-tilburg/roda-jc/2240319/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2016/08/27/netherlands/eredivisie/feyenoord-rotterdam-nv/sbv-excelsior/2240321/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2016/08/27/netherlands/eredivisie/sportclub-heerenveen/bvo-fc-zwolle/2240320/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2016/08/27/netherlands/eredivisie/stichting-fc-twente-65/sparta-rotterdam-bv/2240909/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2016/08/28/netherlands/eredivisie/psv-nv/stichting-fc-groningen/2240322/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2016/08/28/netherlands/eredivisie/stichting-go-ahead-eagles/afc-ajax/2240324/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2016/08/28/netherlands/eredivisie/hfc-ado-den-haag/stichting-heracles-almelo/2240323/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2016/08/28/netherlands/eredivisie/stichting-az/nijmegen-eendracht-combinatie/2240325/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2016/08/05/netherlands/eredivisie/nijmegen-eendracht-combinatie/bvo-fc-zwolle/2240294/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2016/08/06/netherlands/eredivisie/hfc-ado-den-haag/stichting-go-ahead-eagles/2240297/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2016/08/06/netherlands/eredivisie/stichting-fc-twente-65/sbv-excelsior/2240908/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2016/08/06/netherlands/eredivisie/stichting-fc-utrecht/psv-nv/2240296/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2016/08/06/netherlands/eredivisie/sbv-willem-ii-tilburg/sbv-vitesse/2240295/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2016/08/07/netherlands/eredivisie/stichting-fc-groningen/feyenoord-rotterdam-nv/2240298/?ICID=PL_MS_06
# =============Page Done============
# http://de.soccerway.com/matches/2016/04/17/netherlands/eredivisie/sbv-willem-ii-tilburg/hfc-ado-den-haag/2039526/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2016/04/17/netherlands/eredivisie/nijmegen-eendracht-combinatie/stichting-cambuur-leeuwarden-bvo/2039527/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2016/04/17/netherlands/eredivisie/sbv-excelsior/sportclub-heerenveen/2039528/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2016/04/19/netherlands/eredivisie/stichting-fc-groningen/roda-jc/2039529/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2016/04/19/netherlands/eredivisie/psv-nv/sbv-vitesse/2039530/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2016/04/20/netherlands/eredivisie/stichting-fc-utrecht/bv-de-graafschap/2039535/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2016/04/20/netherlands/eredivisie/bvo-fc-zwolle/nijmegen-eendracht-combinatie/2039533/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2016/04/20/netherlands/eredivisie/stichting-heracles-almelo/feyenoord-rotterdam-nv/2039537/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2016/04/20/netherlands/eredivisie/sportclub-heerenveen/afc-ajax/2039534/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2016/04/20/netherlands/eredivisie/stichting-fc-twente-65/sbv-excelsior/2039531/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2016/04/21/netherlands/eredivisie/hfc-ado-den-haag/stichting-az/2039532/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2016/04/21/netherlands/eredivisie/stichting-cambuur-leeuwarden-bvo/sbv-willem-ii-tilburg/2039536/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2016/05/01/netherlands/eredivisie/sbv-vitesse/stichting-fc-utrecht/2039545/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2016/05/01/netherlands/eredivisie/stichting-az/bv-de-graafschap/2039539/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2016/05/01/netherlands/eredivisie/sbv-excelsior/bvo-fc-zwolle/2039543/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2016/05/01/netherlands/eredivisie/stichting-heracles-almelo/hfc-ado-den-haag/2039544/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2016/05/01/netherlands/eredivisie/sbv-willem-ii-tilburg/feyenoord-rotterdam-nv/2039540/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2016/05/01/netherlands/eredivisie/psv-nv/stichting-cambuur-leeuwarden-bvo/2039542/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2016/05/01/netherlands/eredivisie/nijmegen-eendracht-combinatie/roda-jc/2039546/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2016/05/01/netherlands/eredivisie/afc-ajax/stichting-fc-twente-65/2039541/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2016/05/01/netherlands/eredivisie/sportclub-heerenveen/stichting-fc-groningen/2039538/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2016/05/08/netherlands/eredivisie/hfc-ado-den-haag/sportclub-heerenveen/2039554/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2016/05/08/netherlands/eredivisie/stichting-cambuur-leeuwarden-bvo/sbv-excelsior/2039547/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2016/05/08/netherlands/eredivisie/stichting-fc-utrecht/stichting-az/2039548/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2016/05/08/netherlands/eredivisie/bvo-fc-zwolle/psv-nv/2039550/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2016/05/08/netherlands/eredivisie/bv-de-graafschap/afc-ajax/2039551/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2016/05/08/netherlands/eredivisie/stichting-fc-twente-65/sbv-vitesse/2039555/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2016/05/08/netherlands/eredivisie/feyenoord-rotterdam-nv/nijmegen-eendracht-combinatie/2039549/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2016/05/08/netherlands/eredivisie/roda-jc/sbv-willem-ii-tilburg/2039552/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2016/05/08/netherlands/eredivisie/stichting-fc-groningen/stichting-heracles-almelo/2039553/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2016/03/19/netherlands/eredivisie/feyenoord-rotterdam-nv/bv-de-graafschap/2039495/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2016/03/19/netherlands/eredivisie/stichting-cambuur-leeuwarden-bvo/roda-jc/2039497/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2016/03/20/netherlands/eredivisie/stichting-fc-twente-65/stichting-az/2039498/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2016/03/20/netherlands/eredivisie/hfc-ado-den-haag/nijmegen-eendracht-combinatie/2039500/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2016/03/20/netherlands/eredivisie/stichting-fc-groningen/sbv-vitesse/2039499/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2016/03/20/netherlands/eredivisie/psv-nv/afc-ajax/2039501/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2016/04/02/netherlands/eredivisie/bv-de-graafschap/stichting-cambuur-leeuwarden-bvo/2039503/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2016/04/02/netherlands/eredivisie/stichting-heracles-almelo/stichting-fc-utrecht/2039502/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2016/04/02/netherlands/eredivisie/stichting-az/psv-nv/2039504/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2016/04/02/netherlands/eredivisie/sbv-willem-ii-tilburg/stichting-fc-twente-65/2039506/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2016/04/02/netherlands/eredivisie/feyenoord-rotterdam-nv/sbv-excelsior/2039505/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2016/04/03/netherlands/eredivisie/nijmegen-eendracht-combinatie/sbv-vitesse/2039507/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2016/04/03/netherlands/eredivisie/hfc-ado-den-haag/stichting-fc-groningen/2039509/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2016/04/03/netherlands/eredivisie/roda-jc/sportclub-heerenveen/2039508/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2016/04/03/netherlands/eredivisie/afc-ajax/bvo-fc-zwolle/2039510/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2016/04/08/netherlands/eredivisie/bvo-fc-zwolle/roda-jc/2039511/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2016/04/09/netherlands/eredivisie/sbv-excelsior/stichting-heracles-almelo/2039512/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2016/04/09/netherlands/eredivisie/sbv-vitesse/hfc-ado-den-haag/2039514/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2016/04/09/netherlands/eredivisie/stichting-cambuur-leeuwarden-bvo/afc-ajax/2039513/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2016/04/09/netherlands/eredivisie/psv-nv/sbv-willem-ii-tilburg/2039515/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2016/04/10/netherlands/eredivisie/sportclub-heerenveen/stichting-az/2039516/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2016/04/10/netherlands/eredivisie/stichting-fc-groningen/bv-de-graafschap/2039518/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2016/04/10/netherlands/eredivisie/stichting-fc-utrecht/nijmegen-eendracht-combinatie/2039517/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2016/04/10/netherlands/eredivisie/stichting-fc-twente-65/feyenoord-rotterdam-nv/2039519/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2016/04/15/netherlands/eredivisie/bv-de-graafschap/stichting-fc-twente-65/2039520/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2016/04/16/netherlands/eredivisie/sbv-vitesse/stichting-heracles-almelo/2039521/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2016/04/16/netherlands/eredivisie/stichting-az/bvo-fc-zwolle/2039523/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2016/04/16/netherlands/eredivisie/feyenoord-rotterdam-nv/stichting-fc-groningen/2039522/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2016/04/16/netherlands/eredivisie/roda-jc/psv-nv/2039524/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2016/04/17/netherlands/eredivisie/afc-ajax/stichting-fc-utrecht/2039525/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2016/02/26/netherlands/eredivisie/sbv-excelsior/nijmegen-eendracht-combinatie/2039466/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2016/02/27/netherlands/eredivisie/stichting-fc-twente-65/stichting-fc-groningen/2039467/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2016/02/27/netherlands/eredivisie/psv-nv/hfc-ado-den-haag/2039469/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2016/02/27/netherlands/eredivisie/stichting-cambuur-leeuwarden-bvo/bvo-fc-zwolle/2039468/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2016/02/27/netherlands/eredivisie/sbv-vitesse/sbv-willem-ii-tilburg/2039470/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2016/02/28/netherlands/eredivisie/stichting-heracles-almelo/roda-jc/2039471/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2016/02/28/netherlands/eredivisie/stichting-fc-utrecht/feyenoord-rotterdam-nv/2039473/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2016/02/28/netherlands/eredivisie/bv-de-graafschap/sportclub-heerenveen/2039472/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2016/02/28/netherlands/eredivisie/afc-ajax/stichting-az/2039474/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2016/03/04/netherlands/eredivisie/hfc-ado-den-haag/stichting-fc-twente-65/2039475/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2016/03/05/netherlands/eredivisie/bvo-fc-zwolle/bv-de-graafschap/2039476/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2016/03/05/netherlands/eredivisie/stichting-fc-groningen/psv-nv/2039478/?ICID=PL_MS_12
# ...
# =============Page Done============
# http://de.soccerway.com/matches/2009/10/25/netherlands/eredivisie/stichting-az/afc-ajax/781672/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2009/10/25/netherlands/eredivisie/stichting-fc-twente-65/stichting-fc-groningen/781669/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2009/10/25/netherlands/eredivisie/nijmegen-eendracht-combinatie/psv-nv/781675/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2009/10/30/netherlands/eredivisie/vvv-venlo/nac-bv/781676/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2009/10/31/netherlands/eredivisie/sportclub-heerenveen/hfc-ado-den-haag/781678/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2009/10/31/netherlands/eredivisie/psv-nv/sbv-vitesse/781680/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2009/10/31/netherlands/eredivisie/roda-jc/stichting-fc-twente-65/781677/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2009/10/31/netherlands/eredivisie/stichting-fc-groningen/stichting-az/781679/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2009/11/01/netherlands/eredivisie/afc-ajax/feyenoord-rotterdam-nv/781682/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2009/11/01/netherlands/eredivisie/stichting-heracles-almelo/stichting-fc-utrecht/781684/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2009/11/01/netherlands/eredivisie/sparta-rotterdam-bv/nijmegen-eendracht-combinatie/781683/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2009/11/01/netherlands/eredivisie/rkc-waalwijk/sbv-willem-ii-tilburg/781681/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2009/11/06/netherlands/eredivisie/stichting-fc-groningen/stichting-heracles-almelo/781685/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2009/11/07/netherlands/eredivisie/sbv-vitesse/vvv-venlo/781687/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2009/11/07/netherlands/eredivisie/sparta-rotterdam-bv/roda-jc/781688/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2009/11/07/netherlands/eredivisie/nijmegen-eendracht-combinatie/rkc-waalwijk/781686/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2009/11/08/netherlands/eredivisie/nac-bv/sbv-willem-ii-tilburg/781693/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2009/11/08/netherlands/eredivisie/stichting-fc-utrecht/sportclub-heerenveen/781692/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2009/11/08/netherlands/eredivisie/stichting-az/feyenoord-rotterdam-nv/781690/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2009/11/08/netherlands/eredivisie/hfc-ado-den-haag/psv-nv/781689/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2009/11/08/netherlands/eredivisie/stichting-fc-twente-65/afc-ajax/781691/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2009/11/21/netherlands/eredivisie/roda-jc/stichting-az/781697/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2009/11/21/netherlands/eredivisie/rkc-waalwijk/stichting-fc-groningen/781695/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2009/11/21/netherlands/eredivisie/nac-bv/nijmegen-eendracht-combinatie/781694/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2009/11/21/netherlands/eredivisie/stichting-fc-twente-65/sbv-vitesse/781696/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2009/11/22/netherlands/eredivisie/feyenoord-rotterdam-nv/stichting-fc-utrecht/781700/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2009/11/22/netherlands/eredivisie/vvv-venlo/sparta-rotterdam-bv/781702/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2009/11/22/netherlands/eredivisie/sbv-willem-ii-tilburg/hfc-ado-den-haag/781701/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2009/11/22/netherlands/eredivisie/afc-ajax/sportclub-heerenveen/781699/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2009/11/22/netherlands/eredivisie/psv-nv/stichting-heracles-almelo/781698/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2009/09/27/netherlands/eredivisie/afc-ajax/hfc-ado-den-haag/781647/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2009/09/27/netherlands/eredivisie/sparta-rotterdam-bv/sportclub-heerenveen/781646/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2009/09/27/netherlands/eredivisie/nac-bv/feyenoord-rotterdam-nv/781648/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2009/09/27/netherlands/eredivisie/stichting-fc-groningen/sbv-vitesse/781644/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2009/09/27/netherlands/eredivisie/nijmegen-eendracht-combinatie/stichting-heracles-almelo/781645/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2009/09/30/netherlands/eredivisie/nijmegen-eendracht-combinatie/stichting-fc-utrecht/781604/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2009/10/02/netherlands/eredivisie/sbv-vitesse/sparta-rotterdam-bv/781649/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2009/10/03/netherlands/eredivisie/hfc-ado-den-haag/stichting-fc-groningen/781652/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2009/10/03/netherlands/eredivisie/sbv-willem-ii-tilburg/nijmegen-eendracht-combinatie/781653/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2009/10/03/netherlands/eredivisie/stichting-az/nac-bv/781651/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2009/10/03/netherlands/eredivisie/feyenoord-rotterdam-nv/rkc-waalwijk/781650/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2009/10/04/netherlands/eredivisie/roda-jc/afc-ajax/781656/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2009/10/04/netherlands/eredivisie/stichting-fc-utrecht/psv-nv/781657/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2009/10/04/netherlands/eredivisie/sportclub-heerenveen/vvv-venlo/781655/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2009/10/04/netherlands/eredivisie/stichting-heracles-almelo/stichting-fc-twente-65/781654/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2009/10/17/netherlands/eredivisie/afc-ajax/sbv-willem-ii-tilburg/781660/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2009/10/17/netherlands/eredivisie/nac-bv/sbv-vitesse/781661/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2009/10/17/netherlands/eredivisie/stichting-fc-twente-65/stichting-az/781659/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2009/10/17/netherlands/eredivisie/psv-nv/sportclub-heerenveen/781658/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2009/10/18/netherlands/eredivisie/vvv-venlo/roda-jc/781664/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2009/10/18/netherlands/eredivisie/stichting-fc-groningen/stichting-fc-utrecht/781666/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2009/10/18/netherlands/eredivisie/nijmegen-eendracht-combinatie/hfc-ado-den-haag/781665/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2009/10/18/netherlands/eredivisie/rkc-waalwijk/stichting-heracles-almelo/781662/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2009/10/18/netherlands/eredivisie/sparta-rotterdam-bv/feyenoord-rotterdam-nv/781663/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2009/10/23/netherlands/eredivisie/stichting-fc-utrecht/roda-jc/781667/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2009/10/24/netherlands/eredivisie/hfc-ado-den-haag/sparta-rotterdam-bv/781670/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2009/10/24/netherlands/eredivisie/sbv-vitesse/stichting-heracles-almelo/781673/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2009/10/24/netherlands/eredivisie/feyenoord-rotterdam-nv/vvv-venlo/781671/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2009/10/24/netherlands/eredivisie/nac-bv/rkc-waalwijk/781668/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2009/10/25/netherlands/eredivisie/sbv-willem-ii-tilburg/sportclub-heerenveen/781674/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2009/08/28/netherlands/eredivisie/rkc-waalwijk/hfc-ado-den-haag/781613/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2009/08/29/netherlands/eredivisie/nijmegen-eendracht-combinatie/vvv-venlo/781615/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2009/08/29/netherlands/eredivisie/stichting-az/sbv-willem-ii-tilburg/781617/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2009/08/29/netherlands/eredivisie/stichting-fc-utrecht/sparta-rotterdam-bv/781616/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2009/08/30/netherlands/eredivisie/nac-bv/sportclub-heerenveen/781621/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2009/08/30/netherlands/eredivisie/stichting-fc-groningen/psv-nv/781620/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2009/08/30/netherlands/eredivisie/feyenoord-rotterdam-nv/stichting-fc-twente-65/781619/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2009/08/30/netherlands/eredivisie/stichting-heracles-almelo/afc-ajax/781618/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2009/09/12/netherlands/eredivisie/psv-nv/roda-jc/781622/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2009/09/12/netherlands/eredivisie/sportclub-heerenveen/stichting-fc-groningen/781624/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2009/09/12/netherlands/eredivisie/stichting-fc-twente-65/stichting-fc-utrecht/781623/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2009/09/12/netherlands/eredivisie/hfc-ado-den-haag/stichting-az/781625/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2009/09/13/netherlands/eredivisie/sbv-willem-ii-tilburg/feyenoord-rotterdam-nv/781627/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2009/09/13/netherlands/eredivisie/vvv-venlo/stichting-heracles-almelo/781630/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2009/09/13/netherlands/eredivisie/afc-ajax/nac-bv/781629/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2009/09/13/netherlands/eredivisie/sparta-rotterdam-bv/rkc-waalwijk/781628/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2009/09/13/netherlands/eredivisie/sbv-vitesse/nijmegen-eendracht-combinatie/781626/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2009/09/18/netherlands/eredivisie/sbv-willem-ii-tilburg/stichting-fc-groningen/781631/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2009/09/19/netherlands/eredivisie/stichting-heracles-almelo/sparta-rotterdam-bv/781633/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2009/09/19/netherlands/eredivisie/roda-jc/nac-bv/781635/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2009/09/19/netherlands/eredivisie/sbv-vitesse/rkc-waalwijk/781632/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2009/09/19/netherlands/eredivisie/stichting-az/nijmegen-eendracht-combinatie/781634/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2009/09/20/netherlands/eredivisie/hfc-ado-den-haag/stichting-fc-utrecht/781638/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2009/09/20/netherlands/eredivisie/vvv-venlo/afc-ajax/781639/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2009/09/20/netherlands/eredivisie/feyenoord-rotterdam-nv/psv-nv/781637/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2009/09/20/netherlands/eredivisie/sportclub-heerenveen/stichting-fc-twente-65/781636/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2009/09/26/netherlands/eredivisie/stichting-fc-utrecht/stichting-az/781643/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2009/09/26/netherlands/eredivisie/rkc-waalwijk/roda-jc/781642/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2009/09/26/netherlands/eredivisie/psv-nv/sbv-willem-ii-tilburg/781641/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2009/09/26/netherlands/eredivisie/stichting-fc-twente-65/vvv-venlo/781640/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2009/08/02/netherlands/eredivisie/feyenoord-rotterdam-nv/nijmegen-eendracht-combinatie/781583/?ICID=PL_MS_01
# http://de.soccerway.com/matches/2009/08/02/netherlands/eredivisie/hfc-ado-den-haag/nac-bv/781582/?ICID=PL_MS_02
# http://de.soccerway.com/matches/2009/08/02/netherlands/eredivisie/psv-nv/vvv-venlo/781584/?ICID=PL_MS_03
# http://de.soccerway.com/matches/2009/08/07/netherlands/eredivisie/nijmegen-eendracht-combinatie/sportclub-heerenveen/781586/?ICID=PL_MS_04
# http://de.soccerway.com/matches/2009/08/07/netherlands/eredivisie/stichting-az/sparta-rotterdam-bv/781587/?ICID=PL_MS_05
# http://de.soccerway.com/matches/2009/08/08/netherlands/eredivisie/afc-ajax/rkc-waalwijk/781588/?ICID=PL_MS_06
# http://de.soccerway.com/matches/2009/08/08/netherlands/eredivisie/roda-jc/stichting-fc-groningen/781589/?ICID=PL_MS_07
# http://de.soccerway.com/matches/2009/08/09/netherlands/eredivisie/sbv-vitesse/feyenoord-rotterdam-nv/781593/?ICID=PL_MS_08
# http://de.soccerway.com/matches/2009/08/09/netherlands/eredivisie/nac-bv/stichting-heracles-almelo/781591/?ICID=PL_MS_09
# http://de.soccerway.com/matches/2009/08/09/netherlands/eredivisie/stichting-fc-twente-65/psv-nv/781590/?ICID=PL_MS_10
# http://de.soccerway.com/matches/2009/08/09/netherlands/eredivisie/stichting-fc-utrecht/sbv-willem-ii-tilburg/781592/?ICID=PL_MS_11
# http://de.soccerway.com/matches/2009/08/09/netherlands/eredivisie/vvv-venlo/hfc-ado-den-haag/781594/?ICID=PL_MS_12
# http://de.soccerway.com/matches/2009/08/15/netherlands/eredivisie/sparta-rotterdam-bv/sbv-willem-ii-tilburg/781595/?ICID=PL_MS_13
# http://de.soccerway.com/matches/2009/08/15/netherlands/eredivisie/rkc-waalwijk/stichting-az/781597/?ICID=PL_MS_14
# http://de.soccerway.com/matches/2009/08/15/netherlands/eredivisie/hfc-ado-den-haag/stichting-fc-twente-65/781596/?ICID=PL_MS_15
# http://de.soccerway.com/matches/2009/08/15/netherlands/eredivisie/sportclub-heerenveen/sbv-vitesse/781598/?ICID=PL_MS_16
# http://de.soccerway.com/matches/2009/08/16/netherlands/eredivisie/psv-nv/afc-ajax/781601/?ICID=PL_MS_17
# http://de.soccerway.com/matches/2009/08/16/netherlands/eredivisie/stichting-heracles-almelo/feyenoord-rotterdam-nv/781600/?ICID=PL_MS_18
# http://de.soccerway.com/matches/2009/08/16/netherlands/eredivisie/roda-jc/nijmegen-eendracht-combinatie/781599/?ICID=PL_MS_19
# http://de.soccerway.com/matches/2009/08/16/netherlands/eredivisie/stichting-fc-utrecht/vvv-venlo/781602/?ICID=PL_MS_20
# http://de.soccerway.com/matches/2009/08/16/netherlands/eredivisie/stichting-fc-groningen/nac-bv/781603/?ICID=PL_MS_21
# http://de.soccerway.com/matches/2009/08/22/netherlands/eredivisie/sbv-vitesse/hfc-ado-den-haag/781607/?ICID=PL_MS_22
# http://de.soccerway.com/matches/2009/08/22/netherlands/eredivisie/sbv-willem-ii-tilburg/stichting-heracles-almelo/781606/?ICID=PL_MS_23
# http://de.soccerway.com/matches/2009/08/22/netherlands/eredivisie/vvv-venlo/stichting-fc-groningen/781608/?ICID=PL_MS_24
# http://de.soccerway.com/matches/2009/08/23/netherlands/eredivisie/psv-nv/nac-bv/781612/?ICID=PL_MS_25
# http://de.soccerway.com/matches/2009/08/23/netherlands/eredivisie/sportclub-heerenveen/stichting-az/781611/?ICID=PL_MS_26
# http://de.soccerway.com/matches/2009/08/23/netherlands/eredivisie/afc-ajax/sparta-rotterdam-bv/781610/?ICID=PL_MS_27
# http://de.soccerway.com/matches/2009/08/23/netherlands/eredivisie/stichting-fc-twente-65/rkc-waalwijk/781605/?ICID=PL_MS_28
# http://de.soccerway.com/matches/2009/08/23/netherlands/eredivisie/feyenoord-rotterdam-nv/roda-jc/781609/?ICID=PL_MS_29
# http://de.soccerway.com/matches/2009/08/28/netherlands/eredivisie/roda-jc/sbv-vitesse/781614/?ICID=PL_MS_30
# =============Page Done============
# http://de.soccerway.com/matches/2009/07/31/netherlands/eredivisie/sportclub-heerenveen/roda-jc/781577/?ICID=PL_MS_01
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-f6118640ba0a> in <module>()
#      41             soccerway_teams = list(set(filter(None,soccerway_teams)))
#      42             if len(soccerway_teams) > 15:
# ---> 43                 tm_raw = utils.match_club_names([name for name in c.execute('SELECT name, teamID FROM team WHERE patchID IS '+str(find_patch_id(date))+' AND ligaID IS '+str(ligaID))], soccerway_teams)
#      44                 tm = {key:val[1] for key,val in zip(tm_raw.keys(), tm_raw.values())}
#      45             matchID = url_[11]
#
# /home/mace/Documents/Python/soccer/scrape_selenium_soccerway.py in match_club_names(club1_raw, club2_raw, scorer)
#     164     for c2 in club2:
#     165         result = process.extractOne(c2, club1, scorer=scorer)
# --> 166         club1_match_count[result[0]] += 1
#     167         match_dict[c2] = result
#     168
#
# TypeError: 'NoneType' object is not subscriptable
